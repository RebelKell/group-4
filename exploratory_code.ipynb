# %%
# Import dependencies
import pandas as pd

# %%
# Grab first of 5 files
filepath2011 = 'Resources/FARS2011NationalCSV/'
accidents_2011_df = pd.read_csv(filepath2011+'ACCIDENT.CSV')
accidents_2011_df.head()
# Out:
#    STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0      1    10001         1         1         0     0           0        1
# 1      1    10002         1         1         0     0           0        1
# 2      1    10003         2         2         0     0           0        5
# 3      1    10005         1         1         0     0           0        1
# 4      1    10006         1         1         0     0           0        2
#
#    PERSONS  COUNTY  ...  NOT_MIN  ARR_HOUR  ARR_MIN  HOSP_HR  HOSP_MN  CF1  \
# 0        1       5  ...       99        17        2       99       99    0
# 1        1      73  ...       46        23       50       88       88    0
# 2        5      97  ...       99         9       16       99       99    0
# 3        1      15  ...       99        15       40       88       88    0
# 4        2      71  ...       99         6       16       99       99    0
#
#    CF2  CF3  FATALS  DRUNK_DR
# 0    0    0       1         1
# 1    0    0       1         0
# 2    0    0       2         1
# 3    0    0       1         0
# 4    0    0       1         0
#
# [5 rows x 50 columns]

# %%
# Checking columns against the manual, seeing which ones we want
accidents_2011_df.columns
# Out:
# Index(['STATE', 'ST_CASE', 'VE_TOTAL', 'VE_FORMS', 'PVH_INVL', 'PEDS',
#        'PERNOTMVIT', 'PERMVIT', 'PERSONS', 'COUNTY', 'CITY', 'DAY', 'MONTH',
#        'YEAR', 'DAY_WEEK', 'HOUR', 'MINUTE', 'NHS', 'ROAD_FNC', 'ROUTE',
#        'TWAY_ID', 'TWAY_ID2', 'MILEPT', 'LATITUDE', 'LONGITUD', 'SP_JUR',
#        'HARM_EV', 'MAN_COLL', 'RELJCT1', 'RELJCT2', 'TYP_INT', 'REL_ROAD',
#        'WRK_ZONE', 'LGT_COND', 'WEATHER1', 'WEATHER2', 'WEATHER', 'SCH_BUS',
#        'RAIL', 'NOT_HOUR', 'NOT_MIN', 'ARR_HOUR', 'ARR_MIN', 'HOSP_HR',
#        'HOSP_MN', 'CF1', 'CF2', 'CF3', 'FATALS', 'DRUNK_DR'],
#       dtype='object')

# %%
# Oregon is state '41'
# Next step is figuring out all the columns and all the files for each year
# From 'ACCIDENT.CSV' : state, st_case, ve_total, peds + persons, county, month, day_week, year, hour, (road_fnc?), route, latitude, longitud, harm_ev,
    # mann_coll, reljct2, typ_int, rel_road, wrk_zone, lgt_cond, weather, sch_bus, fatals, drunk_dr
# From 'VEHICLE.CSV' : state, st_case, veh_no, reg_state, body_typ, trav_sp, dr_drink, prev_acc, prev_dwi, prev_spd, sppedrel, vspd_lim,
    # acc_type

# %%
# Grabbing 2nd of 5 files
vehicle_2011_df = pd.read_csv(filepath2011+'VEHICLE.CSV', low_memory=False)
vehicle_2011_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  VE_FORMS  NUMOCCS  DAY  MONTH  HOUR  MINUTE  \
# 0      1    10001       1         1        1    4      1    16      51
# 1      1    10002       1         1        1    4      1    23      40
# 2      1    10003       1         2        1    5      1     9      14
# 3      1    10003       2         2        4    5      1     9      14
# 4      1    10005       1         1        1    8      1    15      35
#
#    HARM_EV  ...  VTRAFCON  VTCONT_F  P_CRASH1  P_CRASH2  P_CRASH3  PCRASH4  \
# 0       34  ...         0         0         1        13         1        1
# 1       35  ...         0         0        14         9         1        4
# 2       12  ...         0         0        14        10         1        1
# 3       12  ...         0         0        14        62         1        1
# 4       34  ...         0         0         1        13         1        1
#
#    PCRASH5  ACC_TYPE  DEATHS  DR_DRINK
# 0        4         1       1         1
# 1        4         2       1         0
# 2        2        50       0         1
# 3        1        51       2         0
# 4        4         1       1         0
#
# [5 rows x 127 columns]

# %%
# Checking columns against the manual to see which ones we want
for col in vehicle_2011_df.columns:
    print(col)
# Out:
# STATE
# ST_CASE
# VEH_NO
# VE_FORMS
# NUMOCCS
# DAY
# MONTH
# HOUR
# MINUTE
# HARM_EV
# MAN_COLL
# UNITTYPE
# HIT_RUN
# REG_STAT
# OWNER
# MAKE
# MODEL
# MAK_MOD
# BODY_TYP
# MOD_YEAR
# VIN
# VIN_1
# VIN_2
# VIN_3
# VIN_4
# VIN_5
# VIN_6
# VIN_7
# VIN_8
# VIN_9
# VIN_10
# VIN_11
# VIN_12
# TOW_VEH
# VINTYPE
# VINMAKE
# VINA_MOD
# VIN_BT
# VINMODYR
# VIN_LNGT
# VIN_WGT
# WGTCD_TR
# WHLBS_LG
# WHLBS_SH
# SER_TR
# FUELCODE
# MCYCL_DS
# CARBUR
# CYLINDER
# DISPLACE
# MCYCL_CY
# MCYCL_WT
# TIRE_SZE
# TON_RAT
# TRK_WT
# TRKWTVAR
# VIN_REST
# WHLDRWHL
# J_KNIFE
# MCARR_I1
# MCARR_I2
# MCARR_ID
# GVWR
# V_CONFIG
# CARGO_BT
# HAZ_INV
# HAZ_PLAC
# HAZ_ID
# HAZ_CNO
# HAZ_REL
# BUS_USE
# SPEC_USE
# EMER_USE
# TRAV_SP
# UNDERIDE
# ROLLOVER
# ROLINLOC
# IMPACT1
# IMPACT2
# DEFORMED
# TOWED
# M_HARM
# VEH_SC1
# VEH_SC2
# FIRE_EXP
# DR_PRES
# L_STATE
# DR_ZIP
# L_STATUS
# L_TYPE
# CDL_STAT
# L_ENDORS
# L_COMPL
# L_RESTRI
# DR_HGT
# DR_WGT
# PREV_ACC
# PREV_SUS
# PREV_DWI
# PREV_SPD
# PREV_OTH
# FIRST_MO
# FIRST_YR
# LAST_MO
# LAST_YR
# SPEEDREL
# DR_SF1
# DR_SF2
# DR_SF3
# DR_SF4
# VTRAFWAY
# VNUM_LAN
# VSPD_LIM
# VALIGN
# VPROFILE
# VPAVETYP
# VSURCOND
# VTRAFCON
# VTCONT_F
# P_CRASH1
# P_CRASH2
# P_CRASH3
# PCRASH4
# PCRASH5
# ACC_TYPE
# DEATHS
# DR_DRINK

# %%
# Grabbing 3rd of 5 files
person_2011_df = pd.read_csv(filepath2011 + 'PERSON.CSV', low_memory=False)
person_2011_df.head()
# Out:
#    STATE  ST_CASE  VE_FORMS  VEH_NO  PER_NO  STR_VEH  COUNTY  DAY  MONTH  \
# 0      1    10001         1       1       1        0       5    4      1
# 1      1    10002         1       1       1        0      73    4      1
# 2      1    10003         2       1       1        0      97    5      1
# 3      1    10003         2       2       1        0      97    5      1
# 4      1    10003         2       2       2        0      97    5      1
#
#    HOUR  ...  LAG_HRS  LAG_MINS  P_SF1  P_SF2  P_SF3       CERT_NO  WORK_INJ  \
# 0    16  ...        1        12      0      0      0  ************         0
# 1    23  ...        0         0      0      0      0  ************         0
# 2     9  ...      999        99      0      0      0  ************         8
# 3     9  ...        0         0      0      0      0  ************         0
# 4     9  ...        0         0      0      0      0  ************         0
#
#    HISPANIC  RACE LOCATION
# 0         7     1        0
# 1         2     1        0
# 2         0     0        0
# 3         7     1        0
# 4        99    99        0
#
# [5 rows x 93 columns]

# %%
# Checking columns against the manual to see which ones we want
for col in person_2011_df.columns:
    print(col)
# Out:
# STATE
# ST_CASE
# VE_FORMS
# VEH_NO
# PER_NO
# STR_VEH
# COUNTY
# DAY
# MONTH
# HOUR
# MINUTE
# ROAD_FNC
# HARM_EV
# MAN_COLL
# SCH_BUS
# MAKE
# MAK_MOD
# BODY_TYP
# MOD_YEAR
# VINTYPE
# VINMAKE
# VINA_MOD
# VIN_BT
# VINMODYR
# VIN_LNGT
# VIN_WGT
# WGTCD_TR
# WHLBS_LG
# WHLBS_SH
# SER_TR
# FUELCODE
# MCYCL_DS
# CARBUR
# CYLINDER
# DISPLACE
# MCYCL_CY
# TIRE_SZE
# TON_RAT
# TRK_WT
# TRKWTVAR
# MCYCL_WT
# VIN_REST
# WHLDRWHL
# TOW_VEH
# SPEC_USE
# EMER_USE
# ROLLOVER
# IMPACT1
# IMPACT2
# FIRE_EXP
# AGE
# SEX
# PER_TYP
# INJ_SEV
# SEAT_POS
# REST_USE
# REST_MIS
# AIR_BAG
# EJECTION
# EJ_PATH
# EXTRICAT
# DRINKING
# ALC_DET
# ALC_STATUS
# ATST_TYP
# ALC_RES
# DRUGS
# DRUG_DET
# DSTATUS
# DRUGTST1
# DRUGTST2
# DRUGTST3
# DRUGRES1
# DRUGRES2
# DRUGRES3
# HOSPITAL
# DOA
# DEATH_DA
# DEATH_MO
# DEATH_YR
# DEATH_HR
# DEATH_MN
# DEATH_TM
# LAG_HRS
# LAG_MINS
# P_SF1
# P_SF2
# P_SF3
# CERT_NO
# WORK_INJ
# HISPANIC
# RACE
# LOCATION

# %%
# From PERSON.CSV (person in vehicle): state, st_case, veh_no, per_no, age, sex, per_type, rest_use, rest_mis, drugs

# %%
# Grabbing the fourth of 5 files
distract_2011_df = pd.read_csv(filepath2011 + 'DISTRACT.CSV')
distract_2011_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  MDRDSTRD
# 0      1    10001       1         0
# 1      1    10002       1         0
# 2      1    10003       1         0
# 3      1    10003       2         0
# 4      1    10005       1         0

# %%
# Grabbing the 5th of 5 files
violation_2011_df = pd.read_csv(filepath2011+'VIOLATN.CSV')
violation_2011_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  MVIOLATN
# 0      1    10001       1         0
# 1      1    10002       1         0
# 2      1    10003       1         9
# 3      1    10003       2         0
# 4      1    10005       1         0

# %%
# Slimming the tables to jsut the columns we need
accidents_2011_df = accidents_2011_df[['STATE', 'ST_CASE', 'VE_TOTAL', 'PEDS', 'PERSONS', 'COUNTY', 'MONTH', 'DAY_WEEK', 'YEAR', 'HOUR', 'ROAD_FNC', 'ROUTE', 'LATITUDE', 'LONGITUD', 'HARM_EV', 'MAN_COLL', 'RELJCT2', 'TYP_INT', 'REL_ROAD', 'WRK_ZONE', 'LGT_COND', 'WEATHER', 'SCH_BUS', 'FATALS', 'DRUNK_DR']]
accidents_2011_df.head()
# Out:
#    STATE  ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  \
# 0      1    10001         1     0        1       5      1         3  2011
# 1      1    10002         1     0        1      73      1         3  2011
# 2      1    10003         2     0        5      97      1         4  2011
# 3      1    10005         1     0        1      15      1         7  2011
# 4      1    10006         1     0        2      71      1         7  2011
#
#    HOUR  ...  MAN_COLL  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# 0    16  ...         0        1        1         4         0         5
# 1    23  ...         0        1        1         4         0         3
# 2     9  ...         2        1        1         1         0         1
# 3    15  ...         0        1        1         4         0         1
# 4     6  ...         0        1        1         4         0         3
#
#    WEATHER  SCH_BUS  FATALS  DRUNK_DR
# 0        1        0       1         1
# 1        1        0       1         0
# 2        2        0       2         1
# 3        1        0       1         0
# 4        1        0       1         0
#
# [5 rows x 25 columns]

# %%
# Filtering to just accidents in Oregon 
accidents_2011_df = accidents_2011_df.loc[accidents_2011_df['STATE'] == 41]
accidents_2011_df
# Out:
#        STATE  ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  \
# 21413     41   410001         2     0        3      35      1         1  2011
# 21414     41   410002         1     0        1      19      1         2  2011
# 21415     41   410003         1     2        1      39      1         2  2011
# 21416     41   410004         1     1        1      51      1         3  2011
# 21417     41   410005         2     0        1      51      1         6  2011
# ...      ...      ...       ...   ...      ...     ...    ...       ...   ...
# 21718     41   410314         1     0        2      39      9         2  2011
# 21719     41   410315         1     1        1      47     10         3  2011
# 21720     41   410316         1     0        2       5      9         1  2011
# 21721     41   410317         2     0        3      59     11         2  2011
# 21722     41   410318         1     0        2      33     11         6  2011
#
#        HOUR  ...  MAN_COLL  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# 21413    11  ...         6        1        1         1         0         1
# 21414    16  ...         0        3        3         4         0         2
# 21415     8  ...         0        3        3         4         0         1
# 21416    23  ...         0        1        1         1         0         3
# 21417     9  ...         2        1        1         1         0         1
# ...     ...  ...       ...      ...      ...       ...       ...       ...
# 21718    14  ...         0        2        3         1         0         1
# 21719    19  ...         0        1        1         1         0         2
# 21720    13  ...        98        1        1         4         0         1
# 21721    17  ...         6        2        3         1         8         3
# 21722    11  ...         0        1        1         1         8         1
#
#        WEATHER  SCH_BUS  FATALS  DRUNK_DR
# 21413        1        0       1         0
# 21414        1        0       1         0
# 21415        1        0       1         0
# 21416       10        0       1         0
# 21417       10        0       1         0
# ...        ...      ...     ...       ...
# 21718       98        0       1         0
# 21719        2        0       1         0
# 21720       98        0       1         0
# 21721        1        0       1         1
# 21722       98        0       1         1
#
# [310 rows x 25 columns]

# %%
# Slimming to just the columns we need
vehicle_2011_df = vehicle_2011_df[['STATE', 'ST_CASE', 'VEH_NO', 'REG_STAT', 'BODY_TYP', 'TRAV_SP', 'DR_DRINK', 'PREV_ACC', 'PREV_DWI', 'PREV_SPD', 'SPEEDREL', 'VSPD_LIM', 'ACC_TYPE']]
vehicle_2011_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  REG_STAT  BODY_TYP  TRAV_SP  DR_DRINK  PREV_ACC  \
# 0      1    10001       1         1         1       70         1         1
# 1      1    10002       1         1         4      999         0         0
# 2      1    10003       1         1        15       70         1         0
# 3      1    10003       2         1        14      999         0         0
# 4      1    10005       1         1         4       35         0         2
#
#    PREV_DWI  PREV_SPD  SPEEDREL  VSPD_LIM  ACC_TYPE
# 0         0         0         0        65         1
# 1         0         0         0        40         2
# 2         0         0         1        40        50
# 3         0         0         0        40        51
# 4         0         0         9        35         1

# %%
# Filtering to just the accidents in Oregon
vehicle_2011_df = vehicle_2011_df.loc[vehicle_2011_df['STATE'] == 41]
vehicle_2011_df.head()
# Out:
#        STATE  ST_CASE  VEH_NO  REG_STAT  BODY_TYP  TRAV_SP  DR_DRINK  \
# 31598     41   410001       1         6         6      998         0
# 31599     41   410001       2        41        30      998         0
# 31600     41   410002       1        41         2      998         0
# 31601     41   410003       1        41         4       26         0
# 31602     41   410004       1        99        99      998         0
#
#        PREV_ACC  PREV_DWI  PREV_SPD  SPEEDREL  VSPD_LIM  ACC_TYPE
# 31598         0         0         0         1        55        64
# 31599         0         0         1         0        55        65
# 31600         2         0         0         0        35         1
# 31601         0         0         1         0        25         1
# 31602        99        99        99         9        35        13

# %%
# Slimming to just the columns we need
person_2011_df = person_2011_df[['STATE', 'ST_CASE', 'VEH_NO', 'PER_NO', 'AGE', 'SEX', 'PER_TYP', 'REST_USE', 'REST_MIS', 'DRUGS', 'DOA']]
person_2011_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  PER_NO  AGE  SEX  PER_TYP  REST_USE  REST_MIS  \
# 0      1    10001       1       1   55    2        1         7         0
# 1      1    10002       1       1   24    1        1         3         0
# 2      1    10003       1       1   30    1        1         7         0
# 3      1    10003       2       1   33    2        1         3         0
# 4      1    10003       2       2   52    2        2         3         0
#
#    DRUGS  DOA
# 0      9    0
# 1      9    7
# 2      1    0
# 3      9    7
# 4      8    7

# %%
# Filtering to just the accidents in Oregon
person_2011_df = person_2011_df.loc[person_2011_df['STATE'] == 41]
person_2011_df
# Out:
#        STATE  ST_CASE  VEH_NO  PER_NO  AGE  SEX  PER_TYP  REST_USE  REST_MIS  \
# 52931     41   410001       1       1   64    2        1         3         0
# 52932     41   410001       2       1   23    1        1         3         0
# 52933     41   410001       2       2   23    2        2         3         0
# 52934     41   410002       1       1   78    2        1         3         0
# 52935     41   410003       0       1   74    1        5        96         8
# ...      ...      ...     ...     ...  ...  ...      ...       ...       ...
# 53658     41   410317       1       1   73    1        1         3         0
# 53659     41   410317       1       2   48    1        2         3         0
# 53660     41   410317       2       1   48    1        1        99         0
# 53661     41   410318       1       1   45    2        1        98         0
# 53662     41   410318       1       2   49    1        2         0         0
#
#        DRUGS  DOA
# 52931      9    7
# 52932      9    0
# 52933      9    0
# 52934      0    7
# 52935      0    0
# ...      ...  ...
# 53658      9    0
# 53659      0    0
# 53660      8    7
# 53661      8    0
# 53662      8    0
#
# [732 rows x 11 columns]

# %%
# Filtering to just the accidents in Oregon
distract_2011_df = distract_2011_df.loc[distract_2011_df['STATE'] == 41]
distract_2011_df
# Out:
#        STATE  ST_CASE  VEH_NO  MDRDSTRD
# 31635     41   410001       1        96
# 31636     41   410001       2        96
# 31637     41   410002       1        96
# 31638     41   410003       1        96
# 31639     41   410004       1        99
# ...      ...      ...     ...       ...
# 32067     41   410315       1        96
# 32068     41   410316       1        96
# 32069     41   410317       1        96
# 32070     41   410317       2        96
# 32071     41   410318       1        96
#
# [437 rows x 4 columns]

# %%
# Filtering to just those in Oregon
violation_2011_df = violation_2011_df.loc[violation_2011_df['STATE'] == 41]
violation_2011_df
# Out:
#        STATE  ST_CASE  VEH_NO  MVIOLATN
# 33427     41   410001       1         0
# 33428     41   410001       2         0
# 33429     41   410002       1         0
# 33430     41   410003       1         0
# 33431     41   410004       1         0
# ...      ...      ...     ...       ...
# 33893     41   410315       1         0
# 33894     41   410316       1         0
# 33895     41   410317       1         0
# 33896     41   410317       2         0
# 33897     41   410318       1        11
#
# [471 rows x 4 columns]

# %%
# Re-indexing the different tables to make joining them possible
reindex = distract_2011_df.set_index(['ST_CASE', 'VEH_NO']).drop('STATE', axis=1)
reindex
# Out:
#                 MDRDSTRD
# ST_CASE VEH_NO
# 410001  1             96
#         2             96
# 410002  1             96
# 410003  1             96
# 410004  1             99
# ...                  ...
# 410315  1             96
# 410316  1             96
# 410317  1             96
#         2             96
# 410318  1             96
#
# [437 rows x 1 columns]

# %%
# Re-indexing vehicles
reindex_v = vehicle_2011_df.set_index(['ST_CASE', 'VEH_NO']).drop('STATE', axis=1)
reindex_v
# Out:
#                 REG_STAT  BODY_TYP  TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  \
# ST_CASE VEH_NO
# 410001  1              6         6      998         0         0         0
#         2             41        30      998         0         0         0
# 410002  1             41         2      998         0         2         0
# 410003  1             41         4       26         0         0         0
# 410004  1             99        99      998         0        99        99
# ...                  ...       ...      ...       ...       ...       ...
# 410315  1             41        31      998         0         0         0
# 410316  1             91        80      998         0         1         1
# 410317  1             41        31      998         0         0         0
#         2             41        80      998         1         0         0
# 410318  1             99        99      998         1         0         0
#
#                 PREV_SPD  SPEEDREL  VSPD_LIM  ACC_TYPE
# ST_CASE VEH_NO
# 410001  1              0         1        55        64
#         2              1         0        55        65
# 410002  1              0         0        35         1
# 410003  1              1         0        25         1
# 410004  1             99         9        35        13
# ...                  ...       ...       ...       ...
# 410315  1              1         0        35        13
# 410316  1              1         9        98        99
# 410317  1              0         0        35        68
#         2              0         9        35        69
# 410318  1              0         9        98         0
#
# [436 rows x 10 columns]

# %%
# Merging the double indeces: Registration State, if one vehicle is from OOS, then yes, otherwise no
# Up to 7 vehicles in one accident
# BODY_TYP --> body_type_1, body_type_2, etc. for each car
# TRAV_SP --> highest value if recorded
# DR_DRINK --> Yes if any are yes
# PREV_ACC --> add up except the unknowns
# PREV_DWI --> add up except the unknowns
# PREV_SPD --> add up except the unknowns
# SPEED_REL --> yes if any yesses
# VSPD_LIM --> if any discrepancies then mark highest
# ACC_TYPE --> acc_type_1, acc_type_2, etc for each car
# MDRDSTRD --> If any known, mark as that
# MVIOLATN --> if one, use it

# %%
# Re-indexing violation table
reindex3 = violation_2011_df.set_index(['ST_CASE', 'VEH_NO']).drop('STATE', axis=1)
reindex3
# Out:
#                 MVIOLATN
# ST_CASE VEH_NO
# 410001  1              0
#         2              0
# 410002  1              0
# 410003  1              0
# 410004  1              0
# ...                  ...
# 410315  1              0
# 410316  1              0
# 410317  1              0
#         2              0
# 410318  1             11
#
# [471 rows x 1 columns]

# %%
# Re-indexing person table
person_reindex = person_2011_df.set_index(['ST_CASE', 'VEH_NO', 'PER_NO']).drop('STATE', axis=1)
person_reindex
# Out:
#                        AGE  SEX  PER_TYP  REST_USE  REST_MIS  DRUGS  DOA
# ST_CASE VEH_NO PER_NO
# 410001  1      1        64    2        1         3         0      9    7
#         2      1        23    1        1         3         0      9    0
#                2        23    2        2         3         0      9    0
# 410002  1      1        78    2        1         3         0      0    7
# 410003  0      1        74    1        5        96         8      0    0
# ...                    ...  ...      ...       ...       ...    ...  ...
# 410317  1      1        73    1        1         3         0      9    0
#                2        48    1        2         3         0      0    0
#         2      1        48    1        1        99         0      8    7
# 410318  1      1        45    2        1        98         0      8    0
#                2        49    1        2         0         0      8    0
#
# [732 rows x 7 columns]

# %%
# Merge rows in person:
# age --> average
# sex --> count for each gender
# per_typ --> drop this column
# rest_use --> drop
# rest_mis --> if any yes then yes, otherwise no. if n/a, then it shouldn't matter
# drugs --> yes if any yes, no if no
# doa --> drop

# %%
# Starting the process of merging the rows down to just 'ST_CASE' index, starting by dropping unneeded columns
person_reindex = person_reindex.drop(['PER_TYP', 'REST_USE', 'DOA'], axis=1)
person_reindex[0:10]
# Out:
#                        AGE  SEX  REST_MIS  DRUGS
# ST_CASE VEH_NO PER_NO
# 410001  1      1        64    2         0      9
#         2      1        23    1         0      9
#                2        23    2         0      9
# 410002  1      1        78    2         0      0
# 410003  0      1        74    1         8      0
#                2        63    1         8      0
#         1      1        49    2         0      9
# 410004  0      1        38    1         8      9
#         1      1       999    9         0      9
# 410005  1      1        40    1         0      9

# %%
# This was me testing to see how I could merge via the index
st_case = person_reindex.index[1]
ave_age = person_reindex.loc[st_case[0]]['AGE'].mean()

# %%
# Now switching to accident_df, as that will be the table everything merges to, adding an 'AGE' column
accidents_2011_df['AGE'] = 0
accidents_2011_df.head()
# Out:
#        STATE  ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  \
# 21413     41   410001         2     0        3      35      1         1  2011
# 21414     41   410002         1     0        1      19      1         2  2011
# 21415     41   410003         1     2        1      39      1         2  2011
# 21416     41   410004         1     1        1      51      1         3  2011
# 21417     41   410005         2     0        1      51      1         6  2011
#
#        HOUR  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  WEATHER  \
# 21413    11  ...        1        1         1         0         1        1
# 21414    16  ...        3        3         4         0         2        1
# 21415     8  ...        3        3         4         0         1        1
# 21416    23  ...        1        1         1         0         3       10
# 21417     9  ...        1        1         1         0         1       10
#
#        SCH_BUS  FATALS  DRUNK_DR  AGE
# 21413        0       1         0    0
# 21414        0       1         0    0
# 21415        0       1         0    0
# 21416        0       1         0    0
# 21417        0       1         0    0
#
# [5 rows x 26 columns]

# %%
# Re-indexing to st_case
accidents_reindex = accidents_2011_df.set_index('ST_CASE').drop('STATE', axis=1)
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# ST_CASE                   ...
# 410001          2      2  ...        1        1         1         0         1
# 410002          3      4  ...        3        3         4         0         2
# 410003         15      6  ...        3        3         4         0         1
# 410004         13      6  ...        1        1         1         0         3
# 410005          2      6  ...        1        1         1         0         1
# ...           ...    ...  ...      ...      ...       ...       ...       ...
# 410314         13      6  ...        2        3         1         0         1
# 410315         13      3  ...        1        1         1         0         2
# 410316          6      4  ...        1        1         4         0         1
# 410317         15      6  ...        2        3         1         8         3
# 410318          6      4  ...        1        1         1         8         1
#
#          WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE
# ST_CASE
# 410001         1        0       1         0    0
# 410002         1        0       1         0    0
# 410003         1        0       1         0    0
# 410004        10        0       1         0    0
# 410005        10        0       1         0    0
# ...          ...      ...     ...       ...  ...
# 410314        98        0       1         0    0
# 410315         2        0       1         0    0
# 410316        98        0       1         0    0
# 410317         1        0       1         1    0
# 410318        98        0       1         1    0
#
# [310 rows x 24 columns]

# %%
# Another test to see if this works the way I'd think
accidents_reindex.at[st_case[0], 'AGE'] = ave_age

# %%
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# ST_CASE                   ...
# 410001          2      2  ...        1        1         1         0         1
# 410002          3      4  ...        3        3         4         0         2
# 410003         15      6  ...        3        3         4         0         1
# 410004         13      6  ...        1        1         1         0         3
# 410005          2      6  ...        1        1         1         0         1
# ...           ...    ...  ...      ...      ...       ...       ...       ...
# 410314         13      6  ...        2        3         1         0         1
# 410315         13      3  ...        1        1         1         0         2
# 410316          6      4  ...        1        1         4         0         1
# 410317         15      6  ...        2        3         1         8         3
# 410318          6      4  ...        1        1         1         8         1
#
#          WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE
# ST_CASE
# 410001         1        0       1         0   36
# 410002         1        0       1         0    0
# 410003         1        0       1         0    0
# 410004        10        0       1         0    0
# 410005        10        0       1         0    0
# ...          ...      ...     ...       ...  ...
# 410314        98        0       1         0    0
# 410315         2        0       1         0    0
# 410316        98        0       1         0    0
# 410317         1        0       1         1    0
# 410318        98        0       1         1    0
#
# [310 rows x 24 columns]

# %%
# It works! Now to start building a for loop to add values for each index
person_reindex.index[3]
# Out:
# (410002, 1, 1)

# %%
# Adding average age to accident table
prev_st = 0

for index in person_reindex.index:
    st_case = index[0]
    
    if st_case != prev_st:
        ave_age = person_reindex.loc[st_case]['AGE'].mean()
        
        # unknown ages are listed as 999
        if ave_age > 125:
            ave_age = 999
        
        accidents_reindex.at[st_case, 'AGE'] = ave_age
        
        prev_st = st_case
        
    else:
        prev_st = st_case
        
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# ST_CASE                   ...
# 410001          2      2  ...        1        1         1         0         1
# 410002          3      4  ...        3        3         4         0         2
# 410003         15      6  ...        3        3         4         0         1
# 410004         13      6  ...        1        1         1         0         3
# 410005          2      6  ...        1        1         1         0         1
# ...           ...    ...  ...      ...      ...       ...       ...       ...
# 410314         13      6  ...        2        3         1         0         1
# 410315         13      3  ...        1        1         1         0         2
# 410316          6      4  ...        1        1         4         0         1
# 410317         15      6  ...        2        3         1         8         3
# 410318          6      4  ...        1        1         1         8         1
#
#          WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE
# ST_CASE
# 410001         1        0       1         0   36
# 410002         1        0       1         0   78
# 410003         1        0       1         0   62
# 410004        10        0       1         0  999
# 410005        10        0       1         0   40
# ...          ...      ...     ...       ...  ...
# 410314        98        0       1         0   66
# 410315         2        0       1         0   62
# 410316        98        0       1         0   53
# 410317         1        0       1         1   56
# 410318        98        0       1         1   47
#
# [310 rows x 24 columns]

# %%
# Adding gender columns, will be a count for each accident
accidents_reindex['SEX_1'] = 0
accidents_reindex['SEX_2'] = 0
accidents_reindex['SEX_8'] = 0
accidents_reindex['SEX_9'] = 0

# %%
# Setting gender columns in accidents_df
gender_1 = 0
gender_2 = 0
gender_8 = 0
gender_9 = 0

prev_case = 410001

for index in person_reindex.index:
    st_case = index[0]
    
    if st_case == prev_case:
    
        gender = person_reindex.loc[index]['SEX']
    
        if gender == 1:
            gender_1 += 1
    
        elif gender == 2:
            gender_2 += 1
        
        elif gender == 8:
            gender_8 += 1
        
        elif gender == 9:
            gender_9 += 1
            
        accidents_reindex.at[st_case, 'SEX_1'] = gender_1
        accidents_reindex.at[st_case, 'SEX_2'] = gender_2
        accidents_reindex.at[st_case, 'SEX_8'] = gender_8
        accidents_reindex.at[st_case, 'SEX_9'] = gender_9
        
        prev_case = st_case
            
    elif st_case != prev_case:
        
        gender_1 = 0
        gender_2 = 0
        gender_8 = 0
        gender_9 = 0
        
        gender = person_reindex.loc[index]['SEX']
    
        if gender == 1:
            gender_1 += 1
    
        elif gender == 2:
            gender_2 += 1
        
        elif gender == 8:
            gender_8 += 1
        
        elif gender == 9:
            gender_9 += 1
            
        accidents_reindex.at[st_case, 'SEX_1'] = gender_1
        accidents_reindex.at[st_case, 'SEX_2'] = gender_2
        accidents_reindex.at[st_case, 'SEX_8'] = gender_8
        accidents_reindex.at[st_case, 'SEX_9'] = gender_9
        
        prev_case = st_case
        

accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  LGT_COND  WEATHER  SCH_BUS  FATALS  DRUNK_DR  \
# ST_CASE                   ...
# 410001          2      2  ...         1        1        0       1         0
# 410002          3      4  ...         2        1        0       1         0
# 410003         15      6  ...         1        1        0       1         0
# 410004         13      6  ...         3       10        0       1         0
# 410005          2      6  ...         1       10        0       1         0
# ...           ...    ...  ...       ...      ...      ...     ...       ...
# 410314         13      6  ...         1       98        0       1         0
# 410315         13      3  ...         2        2        0       1         0
# 410316          6      4  ...         1       98        0       1         0
# 410317         15      6  ...         3        1        0       1         1
# 410318          6      4  ...         1       98        0       1         1
#
#          AGE  SEX_1  SEX_2  SEX_8  SEX_9
# ST_CASE
# 410001    36      1      2      0      0
# 410002    78      0      1      0      0
# 410003    62      2      1      0      0
# 410004   999      1      0      0      1
# 410005    40      1      0      0      0
# ...      ...    ...    ...    ...    ...
# 410314    66      0      2      0      0
# 410315    62      2      0      0      0
# 410316    53      1      1      0      0
# 410317    56      3      0      0      0
# 410318    47      1      1      0      0
#
# [310 rows x 28 columns]

# %%
# Looking at person again because it was too far away in the code
person_reindex[0:10]
# Out:
#                        AGE  SEX  REST_MIS  DRUGS
# ST_CASE VEH_NO PER_NO
# 410001  1      1        64    2         0      9
#         2      1        23    1         0      9
#                2        23    2         0      9
# 410002  1      1        78    2         0      0
# 410003  0      1        74    1         8      0
#                2        63    1         8      0
#         1      1        49    2         0      9
# 410004  0      1        38    1         8      9
#         1      1       999    9         0      9
# 410005  1      1        40    1         0      9

# %%
# Set the retstraint misuse column in accidents
accidents_reindex['REST_MIS'] = 0

# %%
# This one is a simple yes/no for the column value
for index in person_reindex.index:
    st_case = index[0]
            
    if person_reindex.loc[index]['REST_MIS'] == 1:
        accidents_reindex.at[st_case, 'REST_MIS'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE  SEX_1  \
# ST_CASE                   ...
# 410001          2      2  ...        1        0       1         0   36      1
# 410002          3      4  ...        1        0       1         0   78      0
# 410003         15      6  ...        1        0       1         0   62      2
# 410004         13      6  ...       10        0       1         0  999      1
# 410005          2      6  ...       10        0       1         0   40      1
# ...           ...    ...  ...      ...      ...     ...       ...  ...    ...
# 410314         13      6  ...       98        0       1         0   66      0
# 410315         13      3  ...        2        0       1         0   62      2
# 410316          6      4  ...       98        0       1         0   53      1
# 410317         15      6  ...        1        0       1         1   56      3
# 410318          6      4  ...       98        0       1         1   47      1
#
#          SEX_2  SEX_8  SEX_9  REST_MIS
# ST_CASE
# 410001       2      0      0         0
# 410002       1      0      0         0
# 410003       1      0      0         0
# 410004       0      0      1         0
# 410005       0      0      0         0
# ...        ...    ...    ...       ...
# 410314       2      0      0         0
# 410315       0      0      0         0
# 410316       1      0      0         0
# 410317       0      0      0         0
# 410318       1      0      0         0
#
# [310 rows x 29 columns]

# %%
# Double checking that it added values
accidents_reindex['REST_MIS'].value_counts()
# Out:
# 0    305
# 1      5
# Name: REST_MIS, dtype: int64

# %%
# set the drugs column in accidents
accidents_reindex['DRUGS'] = 0

# %%
for index in person_reindex.index:
    st_case = index[0]
            
    if person_reindex.loc[index]['DRUGS'] == 1:
        accidents_reindex.at[st_case, 'DRUGS'] = 1
    
    elif (person_reindex.loc[index]['DRUGS'] == 8) or (person_reindex.loc[index]['DRUGS'] == 9):
        accidents_reindex.at[st_case, 'DRUGS'] = 9
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  SCH_BUS  FATALS  DRUNK_DR  AGE  SEX_1  SEX_2  \
# ST_CASE                   ...
# 410001          2      2  ...        0       1         0   36      1      2
# 410002          3      4  ...        0       1         0   78      0      1
# 410003         15      6  ...        0       1         0   62      2      1
# 410004         13      6  ...        0       1         0  999      1      0
# 410005          2      6  ...        0       1         0   40      1      0
# ...           ...    ...  ...      ...     ...       ...  ...    ...    ...
# 410314         13      6  ...        0       1         0   66      0      2
# 410315         13      3  ...        0       1         0   62      2      0
# 410316          6      4  ...        0       1         0   53      1      1
# 410317         15      6  ...        0       1         1   56      3      0
# 410318          6      4  ...        0       1         1   47      1      1
#
#          SEX_8  SEX_9  REST_MIS  DRUGS
# ST_CASE
# 410001       0      0         0      9
# 410002       0      0         0      0
# 410003       0      0         0      9
# 410004       0      1         0      9
# 410005       0      0         0      9
# ...        ...    ...       ...    ...
# 410314       0      0         0      9
# 410315       0      0         0      9
# 410316       0      0         0      9
# 410317       0      0         0      9
# 410318       0      0         0      9
#
# [310 rows x 30 columns]

# %%
# double checking that it added values
accidents_reindex['DRUGS'].value_counts()
# Out:
# 9    260
# 0     46
# 1      4
# Name: DRUGS, dtype: int64

# %%
# Done with the persons dataframe! Time to combine vehicles and accidents

# %%
# Body_typ is too big to have a column for each one, time to consult the manual to see how I can group the types together
reindex_v['BODY_TYP'].value_counts()
# Out:
# 4     105
# 31     62
# 14     40
# 80     39
# 66     35
# 30     33
# 2      31
# 6      16
# 20     16
# 15     12
# 3       8
# 67      6
# 99      5
# 16      4
# 63      3
# 21      3
# 5       3
# 61      3
# 55      2
# 65      2
# 50      1
# 81      1
# 1       1
# 10      1
# 49      1
# 64      1
# 90      1
# 52      1
# Name: BODY_TYP, dtype: int64

# %%
# Too many body types, gonna combine them
# Sedans: 4, 2, 6, 3, 5, 1
# Pickup: 31, 30, 67, 10
# SUV/Van: 14, 20, 15, 16, 21
# motorcycle: 80, 81
# truck: 66, 63, 61, 65, 64
# Bus: 55, 50, 52
# Unknown/Other: 99, 49, 90

# %%
# Setting body_type columns in accidents
accidents_reindex['BT_Sedan'] = 0
accidents_reindex['BT_Pickup'] = 0
accidents_reindex['BT_SUV_Van'] = 0
accidents_reindex['BT_Motorcyle'] = 0
accidents_reindex['BT_Truck'] = 0
accidents_reindex['BT_Bus'] = 0
accidents_reindex['BT_Unknown_Other'] = 0

# %%
# Similar to gender column, adding the types together for each accident
bt_sedan = 0
bt_pickup = 0
bt_suv = 0
bt_motor = 0
bt_truck = 0
bt_bus = 0
bt_unknown = 0


prev_case = 410001

for index in reindex_v.index:
    st_case = index[0]
    
    if st_case == prev_case:
    
        bt = reindex_v.loc[index]['BODY_TYP']
    
        if bt <= 6:
            bt_sedan += 1
    
        elif (bt == 10) or (bt == 30) or (bt == 31) or (bt == 67):
            bt_pickup += 1
        
        elif (bt == 14) or (bt == 15) or (bt == 16) or (bt == 20) or (bt == 21):
            bt_suv += 1
        
        elif (bt == 80) or (bt == 81):
            bt_motor += 1
        
        elif (bt == 61) or (bt == 63) or (bt == 64) or (bt == 65) or (bt == 66):
            bt_truck += 1
            
        elif (bt == 50) or (bt == 52) or (bt == 55):
            bt_bus += 1
            
        elif (bt == 49) or (bt == 90) or (bt == 99):
            bt_unknown += 1
            
        accidents_reindex.at[st_case, 'BT_Sedan'] = bt_sedan
        accidents_reindex.at[st_case, 'BT_Pickup'] = bt_pickup
        accidents_reindex.at[st_case, 'BT_SUV_Van'] = bt_suv
        accidents_reindex.at[st_case, 'BT_Motorcycle'] = bt_motor
        accidents_reindex.at[st_case, 'BT_Truck'] = bt_truck
        accidents_reindex.at[st_case, 'BT_Bus'] = bt_bus
        accidents_reindex.at[st_case, 'BT_Unknown_Other'] = bt_unknown
        
        prev_case = st_case
            
    elif st_case != prev_case:
        
        bt_sedan = 0
        bt_pickup = 0
        bt_suv = 0
        bt_motor = 0
        bt_truck = 0
        bt_bus = 0
        bt_unknown = 0
        
        bt = reindex_v.loc[index]['BODY_TYP']
    
        if bt <= 6:
            bt_sedan += 1
    
        elif (bt == 10) or (bt == 30) or (bt == 31) or (bt == 67):
            bt_pickup += 1
        
        elif (bt == 14) or (bt == 15) or (bt == 16) or (bt == 20) or (bt == 21):
            bt_suv += 1
        
        elif (bt == 80) or (bt == 81):
            bt_motor += 1
        
        elif (bt == 61) or (bt == 63) or (bt == 64) or (bt == 65) or (bt == 66):
            bt_truck += 1
            
        elif (bt == 50) or (bt == 52) or (bt == 55):
            bt_bus += 1
            
        elif (bt == 49) or (bt == 90) or (bt == 99):
            bt_unknown += 1
            
        accidents_reindex.at[st_case, 'BT_Sedan'] = bt_sedan
        accidents_reindex.at[st_case, 'BT_Pickup'] = bt_pickup
        accidents_reindex.at[st_case, 'BT_SUV_Van'] = bt_suv
        accidents_reindex.at[st_case, 'BT_Motorcycle'] = bt_motor
        accidents_reindex.at[st_case, 'BT_Truck'] = bt_truck
        accidents_reindex.at[st_case, 'BT_Bus'] = bt_bus
        accidents_reindex.at[st_case, 'BT_Unknown_Other'] = bt_unknown
        
        prev_case = st_case
        

accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  REST_MIS  DRUGS  BT_Sedan  BT_Pickup  \
# ST_CASE                   ...
# 410001          2      2  ...         0      9         1          1
# 410002          3      4  ...         0      0         1          0
# 410003         15      6  ...         0      9         1          0
# 410004         13      6  ...         0      9         0          0
# 410005          2      6  ...         0      9         1          0
# ...           ...    ...  ...       ...    ...       ...        ...
# 410314         13      6  ...         0      9         0          0
# 410315         13      3  ...         0      9         0          1
# 410316          6      4  ...         0      9         0          0
# 410317         15      6  ...         0      9         0          1
# 410318          6      4  ...         0      9         0          0
#
#          BT_SUV_Van  BT_Motorcyle  BT_Truck  BT_Bus  BT_Unknown_Other  \
# ST_CASE
# 410001            0             0         0       0                 0
# 410002            0             0         0       0                 0
# 410003            0             0         0       0                 0
# 410004            0             0         0       0                 1
# 410005            0             0         1       0                 0
# ...             ...           ...       ...     ...               ...
# 410314            0             0         0       1                 0
# 410315            0             0         0       0                 0
# 410316            0             0         0       0                 0
# 410317            0             0         0       0                 0
# 410318            0             0         0       0                 1
#
#          BT_Motorcycle
# ST_CASE
# 410001             0.0
# 410002             0.0
# 410003             0.0
# 410004             0.0
# 410005             0.0
# ...                ...
# 410314             0.0
# 410315             0.0
# 410316             1.0
# 410317             1.0
# 410318             0.0
#
# [310 rows x 38 columns]

# %%
# Double checking that it added values correctly
accidents_reindex['BT_Sedan'].value_counts()
# Out:
# 0    171
# 1    121
# 2     15
# 6      1
# 3      1
# 4      1
# Name: BT_Sedan, dtype: int64

# %%
# Adding registration state (out of state true/false) to accidents
accidents_reindex['OOS_REG'] = 0

# %%
for index in reindex_v.index:
    st_case = index[0]
            
    if reindex_v.loc[index]['REG_STAT'] == 99:
        accidents_reindex.at[st_case, 'OOS_REG'] = 99
    
    elif reindex_v.loc[index]['REG_STAT'] != 41:
        accidents_reindex.at[st_case, 'OOS_REG'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  DRUGS  BT_Sedan  BT_Pickup  BT_SUV_Van  \
# ST_CASE                   ...
# 410001          2      2  ...      9         1          1           0
# 410002          3      4  ...      0         1          0           0
# 410003         15      6  ...      9         1          0           0
# 410004         13      6  ...      9         0          0           0
# 410005          2      6  ...      9         1          0           0
# ...           ...    ...  ...    ...       ...        ...         ...
# 410314         13      6  ...      9         0          0           0
# 410315         13      3  ...      9         0          1           0
# 410316          6      4  ...      9         0          0           0
# 410317         15      6  ...      9         0          1           0
# 410318          6      4  ...      9         0          0           0
#
#          BT_Motorcyle  BT_Truck  BT_Bus  BT_Unknown_Other  BT_Motorcycle  \
# ST_CASE
# 410001              0         0       0                 0            0.0
# 410002              0         0       0                 0            0.0
# 410003              0         0       0                 0            0.0
# 410004              0         0       0                 1            0.0
# 410005              0         1       0                 0            0.0
# ...               ...       ...     ...               ...            ...
# 410314              0         0       1                 0            0.0
# 410315              0         0       0                 0            0.0
# 410316              0         0       0                 0            1.0
# 410317              0         0       0                 0            1.0
# 410318              0         0       0                 1            0.0
#
#          OOS_REG
# ST_CASE
# 410001         1
# 410002         0
# 410003         0
# 410004        99
# 410005         1
# ...          ...
# 410314         0
# 410315         0
# 410316         1
# 410317         0
# 410318        99
#
# [310 rows x 39 columns]

# %%
# What's left?
# TRAV_SP --> highest value if recorded
# DR_DRINK --> Yes if any are yes
# PREV_ACC --> add up except the unknowns
# PREV_DWI --> add up except the unknowns
# PREV_SPD --> add up except the unknowns
# SPEED_REL --> yes if any yesses
# VSPD_LIM --> if any discrepancies then mark highest
# ACC_TYPE --> acc_type_1, acc_type_2, etc for each car
# MDRDSTRD --> If any known, mark as that
# MVIOLATN --> if one, use it

# %%
# Adding Travel speed to accidents
accidents_reindex['TRAV_SP'] = 0

# %%
speed = 0

for index in reindex_v.index:
    st_case = index[0]
    
    if reindex_v.loc[index]['TRAV_SP'] > 151:
        accidents_reindex.at[st_case, 'TRAV_SP'] = 999
        
    else:
        new_speed = reindex_v.loc[index]['TRAV_SP']
        
        if new_speed > speed:
            accidents_reindex.at[st_case, 'TRAV_SP'] = new_speed
            speed = new_speed

        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_Sedan  BT_Pickup  BT_SUV_Van  BT_Motorcyle  \
# ST_CASE                   ...
# 410001          2      2  ...         1          1           0             0
# 410002          3      4  ...         1          0           0             0
# 410003         15      6  ...         1          0           0             0
# 410004         13      6  ...         0          0           0             0
# 410005          2      6  ...         1          0           0             0
# ...           ...    ...  ...       ...        ...         ...           ...
# 410314         13      6  ...         0          0           0             0
# 410315         13      3  ...         0          1           0             0
# 410316          6      4  ...         0          0           0             0
# 410317         15      6  ...         0          1           0             0
# 410318          6      4  ...         0          0           0             0
#
#          BT_Truck  BT_Bus  BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP
# ST_CASE
# 410001          0       0                 0            0.0        1      999
# 410002          0       0                 0            0.0        0      999
# 410003          0       0                 0            0.0        0       26
# 410004          0       0                 1            0.0       99      999
# 410005          1       0                 0            0.0        1       40
# ...           ...     ...               ...            ...      ...      ...
# 410314          0       1                 0            0.0        0      999
# 410315          0       0                 0            0.0        0      999
# 410316          0       0                 0            1.0        1      999
# 410317          0       0                 0            1.0        0      999
# 410318          0       0                 1            0.0       99      999
#
# [310 rows x 40 columns]

# %%
# Adding dr_drink to accidents
accidents_reindex['DR_DRINK'] = 0

# %%
for index in reindex_v.index:
    st_case = index[0]
            
    if reindex_v.loc[index]['DR_DRINK'] == 1:
        accidents_reindex.at[st_case, 'DR_DRINK'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_Pickup  BT_SUV_Van  BT_Motorcyle  BT_Truck  \
# ST_CASE                   ...
# 410001          2      2  ...          1           0             0         0
# 410002          3      4  ...          0           0             0         0
# 410003         15      6  ...          0           0             0         0
# 410004         13      6  ...          0           0             0         0
# 410005          2      6  ...          0           0             0         1
# ...           ...    ...  ...        ...         ...           ...       ...
# 410314         13      6  ...          0           0             0         0
# 410315         13      3  ...          1           0             0         0
# 410316          6      4  ...          0           0             0         0
# 410317         15      6  ...          1           0             0         0
# 410318          6      4  ...          0           0             0         0
#
#          BT_Bus  BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK
# ST_CASE
# 410001        0                 0            0.0        1      999         0
# 410002        0                 0            0.0        0      999         0
# 410003        0                 0            0.0        0       26         0
# 410004        0                 1            0.0       99      999         0
# 410005        0                 0            0.0        1       40         0
# ...         ...               ...            ...      ...      ...       ...
# 410314        1                 0            0.0        0      999         0
# 410315        0                 0            0.0        0      999         0
# 410316        0                 0            1.0        1      999         0
# 410317        0                 0            1.0        0      999         1
# 410318        0                 1            0.0       99      999         1
#
# [310 rows x 41 columns]

# %%
# Adding prev_acc to accidents
accidents_reindex['PREV_ACC'] = 0

# %%
acc_count = 0
prev_case = 410001

for index in reindex_v.index:
    st_case = index[0]
    
    if st_case == prev_case:
        
        if reindex_v.loc[index]['PREV_ACC'] > 97:
            accidents_reindex.at[st_case, 'PREV_ACC'] = 99
        else:
            acc_count += reindex_v.loc[index]['PREV_ACC']
            
        accidents_reindex.at[st_case, 'PREV_ACC'] = acc_count
        
        prev_case = st_case
    
    elif st_case != prev_case:
        acc_count = 0
        
        if reindex_v.loc[index]['PREV_ACC'] > 97:
            accidents_reindex.at[st_case, 'PREV_ACC'] = 99
        else:
            acc_count += reindex_v.loc[index]['PREV_ACC']
            
        accidents_reindex.at[st_case, 'PREV_ACC'] = acc_count
        
        prev_case = st_case
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_SUV_Van  BT_Motorcyle  BT_Truck  BT_Bus  \
# ST_CASE                   ...
# 410001          2      2  ...           0             0         0       0
# 410002          3      4  ...           0             0         0       0
# 410003         15      6  ...           0             0         0       0
# 410004         13      6  ...           0             0         0       0
# 410005          2      6  ...           0             0         1       0
# ...           ...    ...  ...         ...           ...       ...     ...
# 410314         13      6  ...           0             0         0       1
# 410315         13      3  ...           0             0         0       0
# 410316          6      4  ...           0             0         0       0
# 410317         15      6  ...           0             0         0       0
# 410318          6      4  ...           0             0         0       0
#
#          BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK  PREV_ACC
# ST_CASE
# 410001                  0            0.0        1      999         0         0
# 410002                  0            0.0        0      999         0         2
# 410003                  0            0.0        0       26         0         0
# 410004                  1            0.0       99      999         0         0
# 410005                  0            0.0        1       40         0         0
# ...                   ...            ...      ...      ...       ...       ...
# 410314                  0            0.0        0      999         0         0
# 410315                  0            0.0        0      999         0         0
# 410316                  0            1.0        1      999         0         1
# 410317                  0            1.0        0      999         1         0
# 410318                  1            0.0       99      999         1         0
#
# [310 rows x 42 columns]

# %%
accidents_reindex['PREV_ACC'].value_counts()
# Out:
# 0    261
# 1     39
# 2      9
# 3      1
# Name: PREV_ACC, dtype: int64

# %%
# Adding prev_dwi to accidents
accidents_reindex['PREV_DWI'] = 0

# %%
dwi_count = 0
prev_case = 410001

for index in reindex_v.index:
    st_case = index[0]
    
    if st_case == prev_case:
        
        if reindex_v.loc[index]['PREV_DWI'] > 97:
            accidents_reindex.at[st_case, 'PREV_DWI'] = 99
        else:
            dwi_count += reindex_v.loc[index]['PREV_DWI']
            
        accidents_reindex.at[st_case, 'PREV_DWI'] = dwi_count
        
        prev_case = st_case
    
    elif st_case != prev_case:
        dwi_count = 0
        
        if reindex_v.loc[index]['PREV_DWI'] > 97:
            accidents_reindex.at[st_case, 'PREV_DWI'] = 99
        else:
            dwi_count += reindex_v.loc[index]['PREV_DWI']
            
        accidents_reindex.at[st_case, 'PREV_DWI'] = dwi_count
        
        prev_case = st_case
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_Motorcyle  BT_Truck  BT_Bus  \
# ST_CASE                   ...
# 410001          2      2  ...             0         0       0
# 410002          3      4  ...             0         0       0
# 410003         15      6  ...             0         0       0
# 410004         13      6  ...             0         0       0
# 410005          2      6  ...             0         1       0
# ...           ...    ...  ...           ...       ...     ...
# 410314         13      6  ...             0         0       1
# 410315         13      3  ...             0         0       0
# 410316          6      4  ...             0         0       0
# 410317         15      6  ...             0         0       0
# 410318          6      4  ...             0         0       0
#
#          BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK  \
# ST_CASE
# 410001                  0            0.0        1      999         0
# 410002                  0            0.0        0      999         0
# 410003                  0            0.0        0       26         0
# 410004                  1            0.0       99      999         0
# 410005                  0            0.0        1       40         0
# ...                   ...            ...      ...      ...       ...
# 410314                  0            0.0        0      999         0
# 410315                  0            0.0        0      999         0
# 410316                  0            1.0        1      999         0
# 410317                  0            1.0        0      999         1
# 410318                  1            0.0       99      999         1
#
#          PREV_ACC  PREV_DWI
# ST_CASE
# 410001          0         0
# 410002          2         0
# 410003          0         0
# 410004          0         0
# 410005          0         0
# ...           ...       ...
# 410314          0         0
# 410315          0         0
# 410316          1         1
# 410317          0         0
# 410318          0         0
#
# [310 rows x 43 columns]

# %%
# Adding prev_spd to accidents
accidents_reindex['PREV_SPD'] = 0

# %%
spd_count = 0
prev_case = 410001

for index in reindex_v.index:
    st_case = index[0]
    
    if st_case == prev_case:
        
        if reindex_v.loc[index]['PREV_SPD'] > 97:
            accidents_reindex.at[st_case, 'PREV_SPD'] = 99
        else:
            spd_count += reindex_v.loc[index]['PREV_SPD']
            
        accidents_reindex.at[st_case, 'PREV_SPD'] = spd_count
        
        prev_case = st_case
    
    elif st_case != prev_case:
        spd_count = 0
        
        if reindex_v.loc[index]['PREV_SPD'] > 97:
            accidents_reindex.at[st_case, 'PREV_SPD'] = 99
        else:
            spd_count += reindex_v.loc[index]['PREV_SPD']
            
        accidents_reindex.at[st_case, 'PREV_SPD'] = spd_count
        
        prev_case = st_case
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_Truck  BT_Bus  BT_Unknown_Other  \
# ST_CASE                   ...
# 410001          2      2  ...         0       0                 0
# 410002          3      4  ...         0       0                 0
# 410003         15      6  ...         0       0                 0
# 410004         13      6  ...         0       0                 1
# 410005          2      6  ...         1       0                 0
# ...           ...    ...  ...       ...     ...               ...
# 410314         13      6  ...         0       1                 0
# 410315         13      3  ...         0       0                 0
# 410316          6      4  ...         0       0                 0
# 410317         15      6  ...         0       0                 0
# 410318          6      4  ...         0       0                 1
#
#          BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  \
# ST_CASE
# 410001             0.0        1      999         0         0         0
# 410002             0.0        0      999         0         2         0
# 410003             0.0        0       26         0         0         0
# 410004             0.0       99      999         0         0         0
# 410005             0.0        1       40         0         0         0
# ...                ...      ...      ...       ...       ...       ...
# 410314             0.0        0      999         0         0         0
# 410315             0.0        0      999         0         0         0
# 410316             1.0        1      999         0         1         1
# 410317             1.0        0      999         1         0         0
# 410318             0.0       99      999         1         0         0
#
#          PREV_SPD
# ST_CASE
# 410001          1
# 410002          0
# 410003          1
# 410004          0
# 410005          0
# ...           ...
# 410314          0
# 410315          1
# 410316          1
# 410317          0
# 410318          0
#
# [310 rows x 44 columns]

# %%
# What's left?
# SPEEDREL --> yes if any yesses
# VSPD_LIM --> if any discrepancies then mark highest
# ACC_TYPE --> acc_type_1, acc_type_2, etc for each car
# MDRDSTRD --> If any known, mark as that
# MVIOLATN --> if one, use it

# %%
# Adding speed_rel to accidents
accidents_reindex['SPEED_REL'] = 0

# %%
for index in reindex_v.index:
    st_case = index[0]
            
    if reindex_v.loc[index]['SPEEDREL'] > 5:
        accidents_reindex.at[st_case, 'SPEED_REL'] = 9
    
    elif reindex_v.loc[index]['SPEEDREL'] > 0:
        accidents_reindex.at[st_case, 'SPEED_REL'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_Bus  BT_Unknown_Other  BT_Motorcycle  \
# ST_CASE                   ...
# 410001          2      2  ...       0                 0            0.0
# 410002          3      4  ...       0                 0            0.0
# 410003         15      6  ...       0                 0            0.0
# 410004         13      6  ...       0                 1            0.0
# 410005          2      6  ...       0                 0            0.0
# ...           ...    ...  ...     ...               ...            ...
# 410314         13      6  ...       1                 0            0.0
# 410315         13      3  ...       0                 0            0.0
# 410316          6      4  ...       0                 0            1.0
# 410317         15      6  ...       0                 0            1.0
# 410318          6      4  ...       0                 1            0.0
#
#          OOS_REG  TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  PREV_SPD  SPEED_REL
# ST_CASE
# 410001         1      999         0         0         0         1          1
# 410002         0      999         0         2         0         0          0
# 410003         0       26         0         0         0         1          0
# 410004        99      999         0         0         0         0          9
# 410005         1       40         0         0         0         0          9
# ...          ...      ...       ...       ...       ...       ...        ...
# 410314         0      999         0         0         0         0          0
# 410315         0      999         0         0         0         1          0
# 410316         1      999         0         1         1         1          9
# 410317         0      999         1         0         0         0          9
# 410318        99      999         1         0         0         0          9
#
# [310 rows x 45 columns]

# %%
# Adding vspd_lim to accidents
accidents_reindex['VSPD_LIM'] = 0

# %%
speed = 0

for index in reindex_v.index:
    st_case = index[0]
    
    if reindex_v.loc[index]['VSPD_LIM'] > 95:
        accidents_reindex.at[st_case, 'VSPD_LIM'] = 99
        
    else:
        new_speed = reindex_v.loc[index]['VSPD_LIM']
        
        if new_speed > speed:
            accidents_reindex.at[st_case, 'VSPD_LIM'] = new_speed
            speed = new_speed

        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  BT_Unknown_Other  BT_Motorcycle  OOS_REG  \
# ST_CASE                   ...
# 410001          2      2  ...                 0            0.0        1
# 410002          3      4  ...                 0            0.0        0
# 410003         15      6  ...                 0            0.0        0
# 410004         13      6  ...                 1            0.0       99
# 410005          2      6  ...                 0            0.0        1
# ...           ...    ...  ...               ...            ...      ...
# 410314         13      6  ...                 0            0.0        0
# 410315         13      3  ...                 0            0.0        0
# 410316          6      4  ...                 0            1.0        1
# 410317         15      6  ...                 0            1.0        0
# 410318          6      4  ...                 1            0.0       99
#
#          TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  PREV_SPD  SPEED_REL  VSPD_LIM
# ST_CASE
# 410001       999         0         0         0         1          1        55
# 410002       999         0         2         0         0          0         0
# 410003        26         0         0         0         1          0         0
# 410004       999         0         0         0         0          9         0
# 410005        40         0         0         0         0          9         0
# ...          ...       ...       ...       ...       ...        ...       ...
# 410314       999         0         0         0         0          0        99
# 410315       999         0         0         0         1          0         0
# 410316       999         0         1         1         1          9        99
# 410317       999         1         0         0         0          9         0
# 410318       999         1         0         0         0          9        99
#
# [310 rows x 46 columns]

# %%
# Acc_type another column that needs bucketing. consulting the manual to see the best way that should be done
reindex_v['ACC_TYPE'].value_counts()
# Out:
# 1     62
# 13    55
# 6     49
# 51    38
# 50    38
# 98    36
# 64    16
# 65    16
# 2     13
# 87     9
# 86     9
# 0      8
# 7      8
# 89     7
# 88     7
# 69     5
# 68     5
# 66     4
# 20     4
# 52     4
# 15     4
# 32     4
# 45     3
# 82     3
# 83     3
# 21     3
# 48     2
# 46     2
# 92     2
# 24     2
# 25     2
# 77     1
# 76     1
# 70     1
# 71     1
# 79     1
# 10     1
# 29     1
# 28     1
# 47     1
# 5      1
# 78     1
# 22     1
# 99     1
# Name: ACC_TYPE, dtype: int64

# %%
# Bucket them into configurations:
# ACC_TYPE_A: <=5
# ACC_TYPE_B: <=10
# ACC_TYPE_C: <=16
# ACC_TYPE_D: <=33
# ACC_TYPE_E: <=43
# ACC_TYPE_F: <=49
# ACC_TYPE_G: <=53
# ACC_TYPE_H: <=63
# ACC_TYPE_I: <=67
# ACC_TYPE_J: <=75
# ACC_TYPE_K: <=85
# ACC_TYPE_L: <=91
# ACC_TYPE_M: <=99

# %%
# Adding acc_type columns to accident
accidents_reindex['ACC_TYPE_A'] = 0
accidents_reindex['ACC_TYPE_B'] = 0
accidents_reindex['ACC_TYPE_C'] = 0
accidents_reindex['ACC_TYPE_D'] = 0
accidents_reindex['ACC_TYPE_E'] = 0
accidents_reindex['ACC_TYPE_F'] = 0
accidents_reindex['ACC_TYPE_G'] = 0
accidents_reindex['ACC_TYPE_H'] = 0
accidents_reindex['ACC_TYPE_I'] = 0
accidents_reindex['ACC_TYPE_J'] = 0
accidents_reindex['ACC_TYPE_K'] = 0
accidents_reindex['ACC_TYPE_L'] = 0
accidents_reindex['ACC_TYPE_M'] = 0

# %%
# Doing a count for each accident. I might switch this to a binary, EDIT: will make this binary
type_a = 0
type_b = 0
type_c = 0
type_d = 0
type_e = 0
type_f = 0
type_g = 0
type_h = 0
type_i = 0
type_j = 0
type_k = 0
type_l = 0
type_m = 0

prev_case = 410001

for index in reindex_v.index:
    st_case = index[0]
    
    if st_case == prev_case:
    
        acc_type = reindex_v.loc[index]['ACC_TYPE']
    
        if acc_type <= 5:
            type_a = 1
    
        elif acc_type <= 10:
            type_b = 1
        
        elif acc_type <= 16:
            type_c = 1
        
        elif acc_type <= 33:
            type_d = 1
        
        elif acc_type <= 43:
            type_e = 1
            
        elif acc_type <= 49:
            type_f = 1
            
        elif acc_type <= 53:
            type_g = 1
            
        elif acc_type <= 63:
            type_h = 1
            
        elif acc_type <= 67:
            type_i = 1
            
        elif acc_type <= 75:
            type_j = 1
            
        elif acc_type <= 85:
            type_k = 1
            
        elif acc_type <= 91:
            type_l = 1
            
        elif acc_type <= 99:
            type_m = 1
            
        accidents_reindex.at[st_case, 'ACC_TYPE_A'] = type_a
        accidents_reindex.at[st_case, 'ACC_TYPE_B'] = type_b
        accidents_reindex.at[st_case, 'ACC_TYPE_C'] = type_c
        accidents_reindex.at[st_case, 'ACC_TYPE_D'] = type_d
        accidents_reindex.at[st_case, 'ACC_TYPE_E'] = type_e
        accidents_reindex.at[st_case, 'ACC_TYPE_F'] = type_f
        accidents_reindex.at[st_case, 'ACC_TYPE_G'] = type_g
        accidents_reindex.at[st_case, 'ACC_TYPE_H'] = type_h
        accidents_reindex.at[st_case, 'ACC_TYPE_I'] = type_i
        accidents_reindex.at[st_case, 'ACC_TYPE_J'] = type_j
        accidents_reindex.at[st_case, 'ACC_TYPE_K'] = type_k
        accidents_reindex.at[st_case, 'ACC_TYPE_L'] = type_l
        accidents_reindex.at[st_case, 'ACC_TYPE_M'] = type_m
        
        
        prev_case = st_case
            
    elif st_case != prev_case:
        
        type_a = 0
        type_b = 0
        type_c = 0
        type_d = 0
        type_e = 0
        type_f = 0
        type_g = 0
        type_h = 0
        type_i = 0
        type_j = 0
        type_k = 0
        type_l = 0
        type_m = 0

        acc_type = reindex_v.loc[index]['ACC_TYPE']

        if acc_type <= 5:
            type_a = 1

        elif acc_type <= 10:
            type_b = 1

        elif acc_type <= 16:
            type_c = 1

        elif acc_type <= 33:
            type_d = 1

        elif acc_type <= 43:
            type_e = 1

        elif acc_type <= 49:
            type_f = 1

        elif acc_type <= 53:
            type_g = 1

        elif acc_type <= 63:
            type_h = 1

        elif acc_type <= 67:
            type_i = 1

        elif acc_type <= 75:
            type_j = 1

        elif acc_type <= 85:
            type_k = 1

        elif acc_type <= 91:
            type_l = 1

        elif acc_type <= 99:
            type_m = 1

        accidents_reindex.at[st_case, 'ACC_TYPE_A'] = type_a
        accidents_reindex.at[st_case, 'ACC_TYPE_B'] = type_b
        accidents_reindex.at[st_case, 'ACC_TYPE_C'] = type_c
        accidents_reindex.at[st_case, 'ACC_TYPE_D'] = type_d
        accidents_reindex.at[st_case, 'ACC_TYPE_E'] = type_e
        accidents_reindex.at[st_case, 'ACC_TYPE_F'] = type_f
        accidents_reindex.at[st_case, 'ACC_TYPE_G'] = type_g
        accidents_reindex.at[st_case, 'ACC_TYPE_H'] = type_h
        accidents_reindex.at[st_case, 'ACC_TYPE_I'] = type_i
        accidents_reindex.at[st_case, 'ACC_TYPE_J'] = type_j
        accidents_reindex.at[st_case, 'ACC_TYPE_K'] = type_k
        accidents_reindex.at[st_case, 'ACC_TYPE_L'] = type_l
        accidents_reindex.at[st_case, 'ACC_TYPE_M'] = type_m
        
        
        prev_case = st_case
            
        

accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_D  ACC_TYPE_E  ACC_TYPE_F  ACC_TYPE_G  \
# ST_CASE                   ...
# 410001          2      2  ...           0           0           0           0
# 410002          3      4  ...           0           0           0           0
# 410003         15      6  ...           0           0           0           0
# 410004         13      6  ...           0           0           0           0
# 410005          2      6  ...           0           0           0           1
# ...           ...    ...  ...         ...         ...         ...         ...
# 410314         13      6  ...           0           0           0           0
# 410315         13      3  ...           0           0           0           0
# 410316          6      4  ...           0           0           0           0
# 410317         15      6  ...           0           0           0           0
# 410318          6      4  ...           0           0           0           0
#
#          ACC_TYPE_H  ACC_TYPE_I  ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  \
# ST_CASE
# 410001            0           1           0           0           0
# 410002            0           0           0           0           0
# 410003            0           0           0           0           0
# 410004            0           0           0           0           0
# 410005            0           0           0           0           0
# ...             ...         ...         ...         ...         ...
# 410314            0           0           0           0           0
# 410315            0           0           0           0           0
# 410316            0           0           0           0           0
# 410317            0           0           1           0           0
# 410318            0           0           0           0           0
#
#          ACC_TYPE_M
# ST_CASE
# 410001            0
# 410002            0
# 410003            0
# 410004            0
# 410005            0
# ...             ...
# 410314            0
# 410315            0
# 410316            1
# 410317            0
# 410318            0
#
# [310 rows x 59 columns]

# %%
# adding method of distraction to accidents
accidents_reindex['MDRDSTRD'] = 0

# %%
for index in reindex.index:
    st_case = index[0]
    mdrdstrd = reindex.loc[index]['MDRDSTRD'].values
            
    if (mdrdstrd[0] == 96) or (mdrdstrd[0] == 99):
        accidents_reindex.at[st_case, 'MDRDSTRD'] = 99
    
    else:
        accidents_reindex.at[st_case, 'MDRDSTRD'] = mdrdstrd[0]
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_E  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  \
# ST_CASE                   ...
# 410001          2      2  ...           0           0           0           0
# 410002          3      4  ...           0           0           0           0
# 410003         15      6  ...           0           0           0           0
# 410004         13      6  ...           0           0           0           0
# 410005          2      6  ...           0           0           1           0
# ...           ...    ...  ...         ...         ...         ...         ...
# 410314         13      6  ...           0           0           0           0
# 410315         13      3  ...           0           0           0           0
# 410316          6      4  ...           0           0           0           0
# 410317         15      6  ...           0           0           0           0
# 410318          6      4  ...           0           0           0           0
#
#          ACC_TYPE_I  ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD
# ST_CASE
# 410001            1           0           0           0           0        99
# 410002            0           0           0           0           0        99
# 410003            0           0           0           0           0        99
# 410004            0           0           0           0           0        99
# 410005            0           0           0           0           0        16
# ...             ...         ...         ...         ...         ...       ...
# 410314            0           0           0           0           0        99
# 410315            0           0           0           0           0        99
# 410316            0           0           0           0           1        99
# 410317            0           1           0           0           0        99
# 410318            0           0           0           0           0        99
#
# [310 rows x 60 columns]

# %%
# adding mviolatn to accidents
accidents_reindex['MVIOLATN'] = 0

# %%
for index in reindex3.index:
    st_case = index[0]
    mviolatn = reindex3.loc[index]['MVIOLATN'].values
            
    if mviolatn[0] == 0:
        accidents_reindex.at[st_case, 'MVIOLATN'] = 0
        
    elif (mviolatn[0] == 99) or (mviolatn[0] == 97) or (mviolatn[0] == 95):
        accidents_reindex.at[st_case, 'MVIOLATN'] = 99
    
    else:
        accidents_reindex.at[st_case, 'MVIOLATN'] = mviolatn[0]
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        3      35      1         1  2011    11
# 410002          1     0        1      19      1         2  2011    16
# 410003          1     2        1      39      1         2  2011     8
# 410004          1     1        1      51      1         3  2011    23
# 410005          2     0        1      51      1         6  2011     9
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410314          1     0        2      39      9         2  2011    14
# 410315          1     1        1      47     10         3  2011    19
# 410316          1     0        2       5      9         1  2011    13
# 410317          2     0        3      59     11         2  2011    17
# 410318          1     0        2      33     11         6  2011    11
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  ACC_TYPE_I  \
# ST_CASE                   ...
# 410001          2      2  ...           0           0           0           1
# 410002          3      4  ...           0           0           0           0
# 410003         15      6  ...           0           0           0           0
# 410004         13      6  ...           0           0           0           0
# 410005          2      6  ...           0           1           0           0
# ...           ...    ...  ...         ...         ...         ...         ...
# 410314         13      6  ...           0           0           0           0
# 410315         13      3  ...           0           0           0           0
# 410316          6      4  ...           0           0           0           0
# 410317         15      6  ...           0           0           0           0
# 410318          6      4  ...           0           0           0           0
#
#          ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD  MVIOLATN
# ST_CASE
# 410001            0           0           0           0        99         0
# 410002            0           0           0           0        99         0
# 410003            0           0           0           0        99         0
# 410004            0           0           0           0        99         0
# 410005            0           0           0           0        16        99
# ...             ...         ...         ...         ...       ...       ...
# 410314            0           0           0           0        99         0
# 410315            0           0           0           0        99         0
# 410316            0           0           0           1        99         0
# 410317            1           0           0           0        99         0
# 410318            0           0           0           0        99        11
#
# [310 rows x 61 columns]

# %%
# Saving my hard work into a csv that still needs to be encoded
accidents_reindex.to_csv('Resources/cleaned_data/accidents_2011_unencoded.csv')
