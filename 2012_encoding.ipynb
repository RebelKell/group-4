# %%
# Import dependencies
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
accidents_df = pd.read_csv('Resources/cleaned_data/accidents_2012_unencoded.csv')
accidents_df.head()
# Out:
#    ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# 0   410001         2     0        2      39      1         2  2012    20
# 1   410002         1     1        2      51      1         6  2012    19
# 2   410003         2     0        3      51      1         5  2012    22
# 3   410004         2     0        6      39      1         1  2012    17
# 4   410006         2     0        3      27      1         6  2012    12
#
#    ROAD_FNC  ...  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  ACC_TYPE_I  ACC_TYPE_J  \
# 0         3  ...           0           1           0           0           0
# 1        13  ...           0           0           0           0           0
# 2        13  ...           0           0           0           0           0
# 3         2  ...           0           0           0           1           0
# 4         2  ...           0           0           0           1           0
#
#    ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD  MVIOLATN
# 0           0           0           0        99         0
# 1           0           0           0        99         0
# 2           0           0           0        99         0
# 3           0           0           0        99         0
# 4           0           0           0        99         0
#
# [5 rows x 62 columns]

# %%
# Dropping duplicate columns
accidents_df = accidents_df.drop(['MAN_COLL', 'DR_DRINK'], axis=1)
accidents_df
# Out:
#      ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# 0     410001         2     0        2      39      1         2  2012    20
# 1     410002         1     1        2      51      1         6  2012    19
# 2     410003         2     0        3      51      1         5  2012    22
# 3     410004         2     0        6      39      1         1  2012    17
# 4     410006         2     0        3      27      1         6  2012    12
# ..       ...       ...   ...      ...     ...    ...       ...   ...   ...
# 301   410315         1     1        1      71     10         4  2012    14
# 302   410316         1     0        1      33     10         4  2012    17
# 303   410317         1     0        2      31     10         2  2012    99
# 304   410318         2     0        3      47     11         3  2012    15
# 305   410319         1     0        1      51     12         3  2012    19
#
#      ROAD_FNC  ...  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  ACC_TYPE_I  \
# 0           3  ...           0           1           0           0
# 1          13  ...           0           0           0           0
# 2          13  ...           0           0           0           0
# 3           2  ...           0           0           0           1
# 4           2  ...           0           0           0           1
# ..        ...  ...         ...         ...         ...         ...
# 301        14  ...           0           0           0           0
# 302         4  ...           0           0           0           0
# 303         5  ...           0           0           0           0
# 304         3  ...           0           0           0           0
# 305         4  ...           0           0           0           0
#
#      ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD  MVIOLATN
# 0             0           0           0           0        99         0
# 1             0           0           0           0        99         0
# 2             0           0           0           0        99         0
# 3             0           0           0           0        99         0
# 4             0           0           0           0        99         0
# ..          ...         ...         ...         ...       ...       ...
# 301           0           0           0           0        99         0
# 302           0           0           0           1        99         0
# 303           0           0           0           1        99         0
# 304           0           0           0           0        99         0
# 305           0           0           0           0        99         0
#
# [306 rows x 60 columns]

# %%
accidents_df = accidents_df.set_index('ST_CASE')
accidents_df
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      39      1         2  2012    20
# 410002          1     1        2      51      1         6  2012    19
# 410003          2     0        3      51      1         5  2012    22
# 410004          2     0        6      39      1         1  2012    17
# 410006          2     0        3      27      1         6  2012    12
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410315          1     1        1      71     10         4  2012    14
# 410316          1     0        1      33     10         4  2012    17
# 410317          1     0        2      31     10         2  2012    99
# 410318          2     0        3      47     11         3  2012    15
# 410319          1     0        1      51     12         3  2012    19
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  ACC_TYPE_I  \
# ST_CASE                   ...
# 410001          3      4  ...           0           1           0           0
# 410002         13      3  ...           0           0           0           0
# 410003         13      3  ...           0           0           0           0
# 410004          2      3  ...           0           0           0           1
# 410006          2      3  ...           0           0           0           1
# ...           ...    ...  ...         ...         ...         ...         ...
# 410315         14      3  ...           0           0           0           0
# 410316          4      4  ...           0           0           0           0
# 410317          5      4  ...           0           0           0           0
# 410318          3      3  ...           0           0           0           0
# 410319          4      4  ...           0           0           0           0
#
#          ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD  MVIOLATN
# ST_CASE
# 410001            0           0           0           0        99         0
# 410002            0           0           0           0        99         0
# 410003            0           0           0           0        99         0
# 410004            0           0           0           0        99         0
# 410006            0           0           0           0        99         0
# ...             ...         ...         ...         ...       ...       ...
# 410315            0           0           0           0        99         0
# 410316            0           0           0           1        99         0
# 410317            0           0           0           1        99         0
# 410318            0           0           0           0        99         0
# 410319            0           0           0           0        99         0
#
# [306 rows x 59 columns]

# %%
# creating buckets: 1-7 non-collision, a
# 8, 9, 15 pedestrian, cyclist, b
# 10 train, c
# 11 animal, d
# 12-14 motor vehicle, e
# 16-18 falling object, f
# 19-53, 57-59 into object, off road, g
# 54,55,72,73 cargo, h
# else, other/unknown, i

# %%
# Bucketing HARM_EV
accidents_df['HARM_EV_a'] = 0
accidents_df['HARM_EV_b'] = 0
accidents_df['HARM_EV_c'] = 0
accidents_df['HARM_EV_d'] = 0
accidents_df['HARM_EV_e'] = 0
accidents_df['HARM_EV_f'] = 0
accidents_df['HARM_EV_g'] = 0
accidents_df['HARM_EV_h'] = 0
accidents_df['HARM_EV_i'] = 0

# %%
for index in accidents_df.index:
    
    event = accidents_df.loc[index]['HARM_EV']
    
    if event <= 7:
        accidents_df.at[index, 'HARM_EV_a'] = 1
    
    elif (event <= 9) or (event == 15):
        accidents_df.at[index, 'HARM_EV_b'] = 1
        
    elif event == 10:
        accidents_df.at[index, 'HARM_EV_c'] = 1
        
    elif event == 11:
        accidents_df.at[index, 'HARM_EV_d'] = 1
        
    elif event <= 14:
        accidents_df.at[index, 'HARM_EV_e'] = 1
        
    elif event <= 18:
        accidents_df.at[index, 'HARM_EV_f'] = 1
        
    elif (event <= 53) or (event == 57) or (event == 58) or (event == 59):
        accidents_df.at[index, 'HARM_EV_g'] = 1
        
    elif event <= 73:
        accidents_df.at[index, 'HARM_EV_h'] = 1
        
    else:
        accidents_df.at[index, 'HARM_EV_i'] = 1

accidents_df.head()
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      39      1         2  2012    20
# 410002          1     1        2      51      1         6  2012    19
# 410003          2     0        3      51      1         5  2012    22
# 410004          2     0        6      39      1         1  2012    17
# 410006          2     0        3      27      1         6  2012    12
#
#          ROAD_FNC  ROUTE  ...  MVIOLATN  HARM_EV_a  HARM_EV_b  HARM_EV_c  \
# ST_CASE                   ...
# 410001          3      4  ...         0          0          0          0
# 410002         13      3  ...         0          0          1          0
# 410003         13      3  ...         0          0          0          0
# 410004          2      3  ...         0          0          0          0
# 410006          2      3  ...         0          0          0          0
#
#          HARM_EV_d  HARM_EV_e  HARM_EV_f  HARM_EV_g  HARM_EV_h  HARM_EV_i
# ST_CASE
# 410001           0          1          0          0          0          0
# 410002           0          0          0          0          0          0
# 410003           0          1          0          0          0          0
# 410004           0          1          0          0          0          0
# 410006           0          1          0          0          0          0
#
# [5 rows x 68 columns]

# %%
# drop harm_ev
accidents_df = accidents_df.drop('HARM_EV', axis = 1)

# %%
# Encoding with get_dummies()
encoded_df = pd.get_dummies(accidents_df, columns=['ROAD_FNC', 'ROUTE', 'RELJCT2', 'TYP_INT', 'REL_ROAD', 'WRK_ZONE', 'LGT_COND', 'WEATHER', 'DRUGS', 'OOS_REG', 'MDRDSTRD', 'MVIOLATN'])
encoded_df.head()
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      39      1         2  2012    20
# 410002          1     1        2      51      1         6  2012    19
# 410003          2     0        3      51      1         5  2012    22
# 410004          2     0        6      39      1         1  2012    17
# 410006          2     0        3      27      1         6  2012    12
#
#           LATITUDE    LONGITUD  ...  MVIOLATN_0  MVIOLATN_1  MVIOLATN_2  \
# ST_CASE                         ...
# 410001   44.200944 -123.171875  ...           1           0           0
# 410002   45.481117 -122.673397  ...           1           0           0
# 410003   45.472681 -122.640083  ...           1           0           0
# 410004   44.067608 -123.458653  ...           1           0           0
# 410006   45.469267 -121.562647  ...           1           0           0
#
#          MVIOLATN_7  MVIOLATN_9  MVIOLATN_11  MVIOLATN_31  MVIOLATN_46  \
# ST_CASE
# 410001            0           0            0            0            0
# 410002            0           0            0            0            0
# 410003            0           0            0            0            0
# 410004            0           0            0            0            0
# 410006            0           0            0            0            0
#
#          MVIOLATN_71  MVIOLATN_72
# ST_CASE
# 410001             0            0
# 410002             0            0
# 410003             0            0
# 410004             0            0
# 410006             0            0
#
# [5 rows x 132 columns]

# %%
# Things we don't want to be scaled: county, year, latitude, longitud
prescaled_df = encoded_df.drop(['COUNTY', 'YEAR', 'LATITUDE', 'LONGITUD'], axis=1)
prescaled_df
# Out:
#          VE_TOTAL  PEDS  PERSONS  MONTH  DAY_WEEK  HOUR  SCH_BUS  FATALS  \
# ST_CASE
# 410001          2     0        2      1         2    20        0       2
# 410002          1     1        2      1         6    19        0       1
# 410003          2     0        3      1         5    22        0       1
# 410004          2     0        6      1         1    17        0       1
# 410006          2     0        3      1         6    12        0       2
# ...           ...   ...      ...    ...       ...   ...      ...     ...
# 410315          1     1        1     10         4    14        0       1
# 410316          1     0        1     10         4    17        0       1
# 410317          1     0        2     10         2    99        0       1
# 410318          2     0        3     11         3    15        0       1
# 410319          1     0        1     12         3    19        0       1
#
#          DRUNK_DR  AGE  ...  MVIOLATN_0  MVIOLATN_1  MVIOLATN_2  MVIOLATN_7  \
# ST_CASE                 ...
# 410001          1   37  ...           1           0           0           0
# 410002          0   45  ...           1           0           0           0
# 410003          1   31  ...           1           0           0           0
# 410004          0   21  ...           1           0           0           0
# 410006          2   35  ...           1           0           0           0
# ...           ...  ...  ...         ...         ...         ...         ...
# 410315          0   44  ...           1           0           0           0
# 410316          0   71  ...           1           0           0           0
# 410317          1   36  ...           1           0           0           0
# 410318          0  999  ...           1           0           0           0
# 410319          0   89  ...           1           0           0           0
#
#          MVIOLATN_9  MVIOLATN_11  MVIOLATN_31  MVIOLATN_46  MVIOLATN_71  \
# ST_CASE
# 410001            0            0            0            0            0
# 410002            0            0            0            0            0
# 410003            0            0            0            0            0
# 410004            0            0            0            0            0
# 410006            0            0            0            0            0
# ...             ...          ...          ...          ...          ...
# 410315            0            0            0            0            0
# 410316            0            0            0            0            0
# 410317            0            0            0            0            0
# 410318            0            0            0            0            0
# 410319            0            0            0            0            0
#
#          MVIOLATN_72
# ST_CASE
# 410001             0
# 410002             0
# 410003             0
# 410004             0
# 410006             0
# ...              ...
# 410315             0
# 410316             0
# 410317             0
# 410318             0
# 410319             0
#
# [306 rows x 128 columns]

# %%
# making unknown age into an 'everage' age
for index in prescaled_df.index:
    
    if prescaled_df.loc[index]['AGE'] == 999:
        prescaled_df.at[index, 'AGE'] = 40
        
prescaled_df.head()
# Out:
#          VE_TOTAL  PEDS  PERSONS  MONTH  DAY_WEEK  HOUR  SCH_BUS  FATALS  \
# ST_CASE
# 410001          2     0        2      1         2    20        0       2
# 410002          1     1        2      1         6    19        0       1
# 410003          2     0        3      1         5    22        0       1
# 410004          2     0        6      1         1    17        0       1
# 410006          2     0        3      1         6    12        0       2
#
#          DRUNK_DR  AGE  ...  MVIOLATN_0  MVIOLATN_1  MVIOLATN_2  MVIOLATN_7  \
# ST_CASE                 ...
# 410001          1   37  ...           1           0           0           0
# 410002          0   45  ...           1           0           0           0
# 410003          1   31  ...           1           0           0           0
# 410004          0   21  ...           1           0           0           0
# 410006          2   35  ...           1           0           0           0
#
#          MVIOLATN_9  MVIOLATN_11  MVIOLATN_31  MVIOLATN_46  MVIOLATN_71  \
# ST_CASE
# 410001            0            0            0            0            0
# 410002            0            0            0            0            0
# 410003            0            0            0            0            0
# 410004            0            0            0            0            0
# 410006            0            0            0            0            0
#
#          MVIOLATN_72
# ST_CASE
# 410001             0
# 410002             0
# 410003             0
# 410004             0
# 410006             0
#
# [5 rows x 128 columns]

# %%
# Scaling
data_scaler = StandardScaler()

# %%
scaled_data = data_scaler.fit_transform(prescaled_df)
scaled_data
# Out:
# array([[ 0.97797841, -0.52334119, -0.11047069, ..., -0.09950372,
#         -0.05725983, -0.05725983],
#        [-0.67539945,  1.67039039, -0.11047069, ..., -0.09950372,
#         -0.05725983, -0.05725983],
#        [ 0.97797841, -0.52334119,  0.22422269, ..., -0.09950372,
#         -0.05725983, -0.05725983],
#        ...,
#        [-0.67539945, -0.52334119, -0.11047069, ..., -0.09950372,
#         -0.05725983, -0.05725983],
#        [ 0.97797841, -0.52334119,  0.22422269, ..., -0.09950372,
#         -0.05725983, -0.05725983],
#        [-0.67539945, -0.52334119, -0.44516407, ..., -0.09950372,
#         -0.05725983, -0.05725983]])

# %%
df_columns = prescaled_df.columns

# %%
# Creating a dataframe from the data
scaled_df = pd.DataFrame(data=scaled_data, columns=df_columns)
scaled_df
# Out:
#      VE_TOTAL      PEDS   PERSONS     MONTH  DAY_WEEK      HOUR  SCH_BUS  \
# 0    0.977978 -0.523341 -0.110471 -1.837742 -1.022394  0.288758      0.0
# 1   -0.675399  1.670390 -0.110471 -1.837742  0.842599  0.222719      0.0
# 2    0.977978 -0.523341  0.224223 -1.837742  0.376351  0.420835      0.0
# 3    0.977978 -0.523341  1.228303 -1.837742 -1.488643  0.090641      0.0
# 4    0.977978 -0.523341  0.224223 -1.837742  0.842599 -0.239552      0.0
# ..        ...       ...       ...       ...       ...       ...      ...
# 301 -0.675399  1.670390 -0.445164  0.886231 -0.089898 -0.107475      0.0
# 302 -0.675399 -0.523341 -0.445164  0.886231 -0.089898  0.090641      0.0
# 303 -0.675399 -0.523341 -0.110471  0.886231 -1.022394  5.505818      0.0
# 304  0.977978 -0.523341  0.224223  1.188895 -0.556146 -0.041436      0.0
# 305 -0.675399 -0.523341 -0.445164  1.491558 -0.556146  0.222719      0.0
#
#        FATALS  DRUNK_DR       AGE  ...  MVIOLATN_0  MVIOLATN_1  MVIOLATN_2  \
# 0    1.589171  1.526006 -0.396040  ...    0.317363   -0.183804   -0.099504
# 1   -0.179143 -0.616002  0.089684  ...    0.317363   -0.183804   -0.099504
# 2   -0.179143  1.526006 -0.760333  ...    0.317363   -0.183804   -0.099504
# 3   -0.179143 -0.616002 -1.367489  ...    0.317363   -0.183804   -0.099504
# 4    1.589171  3.668015 -0.517471  ...    0.317363   -0.183804   -0.099504
# ..        ...       ...       ...  ...         ...         ...         ...
# 301 -0.179143 -0.616002  0.028969  ...    0.317363   -0.183804   -0.099504
# 302 -0.179143 -0.616002  1.668288  ...    0.317363   -0.183804   -0.099504
# 303 -0.179143  1.526006 -0.456755  ...    0.317363   -0.183804   -0.099504
# 304 -0.179143 -0.616002 -0.213893  ...    0.317363   -0.183804   -0.099504
# 305 -0.179143 -0.616002  2.761168  ...    0.317363   -0.183804   -0.099504
#
#      MVIOLATN_7  MVIOLATN_9  MVIOLATN_11  MVIOLATN_31  MVIOLATN_46  \
# 0     -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 1     -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 2     -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 3     -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 4     -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# ..          ...         ...          ...          ...          ...
# 301   -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 302   -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 303   -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 304   -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
# 305   -0.081111   -0.081111    -0.128885     -0.05726    -0.099504
#
#      MVIOLATN_71  MVIOLATN_72
# 0       -0.05726     -0.05726
# 1       -0.05726     -0.05726
# 2       -0.05726     -0.05726
# 3       -0.05726     -0.05726
# 4       -0.05726     -0.05726
# ..           ...          ...
# 301     -0.05726     -0.05726
# 302     -0.05726     -0.05726
# 303     -0.05726     -0.05726
# 304     -0.05726     -0.05726
# 305     -0.05726     -0.05726
#
# [306 rows x 128 columns]

# %%
# Adding st_case back to df
scaled_df['ST_CASE'] = prescaled_df.index
scaled_df
# Out:
#      VE_TOTAL      PEDS   PERSONS     MONTH  DAY_WEEK      HOUR  SCH_BUS  \
# 0    0.977978 -0.523341 -0.110471 -1.837742 -1.022394  0.288758      0.0
# 1   -0.675399  1.670390 -0.110471 -1.837742  0.842599  0.222719      0.0
# 2    0.977978 -0.523341  0.224223 -1.837742  0.376351  0.420835      0.0
# 3    0.977978 -0.523341  1.228303 -1.837742 -1.488643  0.090641      0.0
# 4    0.977978 -0.523341  0.224223 -1.837742  0.842599 -0.239552      0.0
# ..        ...       ...       ...       ...       ...       ...      ...
# 301 -0.675399  1.670390 -0.445164  0.886231 -0.089898 -0.107475      0.0
# 302 -0.675399 -0.523341 -0.445164  0.886231 -0.089898  0.090641      0.0
# 303 -0.675399 -0.523341 -0.110471  0.886231 -1.022394  5.505818      0.0
# 304  0.977978 -0.523341  0.224223  1.188895 -0.556146 -0.041436      0.0
# 305 -0.675399 -0.523341 -0.445164  1.491558 -0.556146  0.222719      0.0
#
#        FATALS  DRUNK_DR       AGE  ...  MVIOLATN_1  MVIOLATN_2  MVIOLATN_7  \
# 0    1.589171  1.526006 -0.396040  ...   -0.183804   -0.099504   -0.081111
# 1   -0.179143 -0.616002  0.089684  ...   -0.183804   -0.099504   -0.081111
# 2   -0.179143  1.526006 -0.760333  ...   -0.183804   -0.099504   -0.081111
# 3   -0.179143 -0.616002 -1.367489  ...   -0.183804   -0.099504   -0.081111
# 4    1.589171  3.668015 -0.517471  ...   -0.183804   -0.099504   -0.081111
# ..        ...       ...       ...  ...         ...         ...         ...
# 301 -0.179143 -0.616002  0.028969  ...   -0.183804   -0.099504   -0.081111
# 302 -0.179143 -0.616002  1.668288  ...   -0.183804   -0.099504   -0.081111
# 303 -0.179143  1.526006 -0.456755  ...   -0.183804   -0.099504   -0.081111
# 304 -0.179143 -0.616002 -0.213893  ...   -0.183804   -0.099504   -0.081111
# 305 -0.179143 -0.616002  2.761168  ...   -0.183804   -0.099504   -0.081111
#
#      MVIOLATN_9  MVIOLATN_11  MVIOLATN_31  MVIOLATN_46  MVIOLATN_71  \
# 0     -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 1     -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 2     -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 3     -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 4     -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# ..          ...          ...          ...          ...          ...
# 301   -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 302   -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 303   -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 304   -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
# 305   -0.081111    -0.128885     -0.05726    -0.099504     -0.05726
#
#      MVIOLATN_72  ST_CASE
# 0       -0.05726   410001
# 1       -0.05726   410002
# 2       -0.05726   410003
# 3       -0.05726   410004
# 4       -0.05726   410006
# ..           ...      ...
# 301     -0.05726   410315
# 302     -0.05726   410316
# 303     -0.05726   410317
# 304     -0.05726   410318
# 305     -0.05726   410319
#
# [306 rows x 129 columns]

# %%
# save the scaled data
scaled_df.to_csv('Resources/cleaned_data/2012_scaled_data.csv')
