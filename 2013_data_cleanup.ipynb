# %%
import pandas as pd

# %%
filepath2013 = 'Resources/raw_data/FARS2013NationalCSV/'
accidents_2013_df = pd.read_csv(filepath2013+'ACCIDENT.CSV')
accidents_2013_df.head()
# Out:
#    STATE  ST_CASE  VE_TOTAL  VE_FORMS  PVH_INVL  PEDS  PERNOTMVIT  PERMVIT  \
# 0      1    10001         1         1         0     0           0        8
# 1      1    10002         2         2         0     0           0        2
# 2      1    10003         1         1         0     0           0        1
# 3      1    10004         1         1         0     0           0        3
# 4      1    10005         2         2         0     0           0        3
#
#    PERSONS  COUNTY  ...  NOT_MIN  ARR_HOUR  ARR_MIN  HOSP_HR  HOSP_MN  CF1  \
# 0        8     115  ...       99         1        7       99       99    0
# 1        2      55  ...       99        21       33       99       99    0
# 2        1      89  ...       99        11       54       99       99    0
# 3        3      73  ...       99        12       33       99       99    0
# 4        3     125  ...       99        18       29       99       99    0
#
#    CF2  CF3  FATALS  DRUNK_DR
# 0    0    0       2         0
# 1    0    0       1         0
# 2    0    0       1         0
# 3    0    0       2         0
# 4    0    0       1         0
#
# [5 rows x 50 columns]

# %%
# Grabbing 2nd of 5 files
vehicle_2013_df = pd.read_csv(filepath2013+'VEHICLE.CSV', low_memory=False)
vehicle_2013_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  VE_FORMS  NUMOCCS  DAY  MONTH  HOUR  MINUTE  \
# 0      1    10001       1         1        8    6      1     0      55
# 1      1    10002       1         2        1    3      1    21      24
# 2      1    10002       2         2        1    3      1    21      24
# 3      1    10003       1         1        1    6      1    11      45
# 4      1    10004       1         1        3    6      1    12      25
#
#    HARM_EV  ...  VTRAFCON  VTCONT_F  P_CRASH1  P_CRASH2  P_CRASH3  PCRASH4  \
# 0       42  ...         0         0         1         1         1        4
# 1       12  ...         0         0         1        66         8        1
# 2       12  ...        20         3         1        17         1        1
# 3       30  ...         0         0         1        13         1        1
# 4       24  ...         0         0         1         6         1        3
#
#    PCRASH5  ACC_TYPE  DEATHS  DR_DRINK
# 0        4         7       2         0
# 1        2        88       0         0
# 2        1        89       1         0
# 3        4         1       1         0
# 4        4         7       2         0
#
# [5 rows x 102 columns]

# %%
# Grabbing 3rd of 5 files
person_2013_df = pd.read_csv(filepath2013 + 'PERSON.CSV', low_memory=False)
person_2013_df.head()
# Out:
#    STATE  ST_CASE  VE_FORMS  VEH_NO  PER_NO  STR_VEH  COUNTY  DAY  MONTH  \
# 0      1    10001         1       1       1        0     115    6      1
# 1      1    10001         1       1       2        0     115    6      1
# 2      1    10001         1       1       3        0     115    6      1
# 3      1    10001         1       1       4        0     115    6      1
# 4      1    10001         1       1       5        0     115    6      1
#
#    HOUR  ...  LAG_HRS  LAG_MINS  P_SF1  P_SF2  P_SF3       CERT_NO  WORK_INJ  \
# 0     0  ...      999        99      0      0      0  ************         8
# 1     0  ...      999        99      0      0      0  ************         8
# 2     0  ...        0        25      0      0      0  ************         0
# 3     0  ...      999        99      0      0      0  ************         8
# 4     0  ...      999        99      0      0      0  ************         8
#
#    HISPANIC  RACE  LOCATION
# 0         0     0         0
# 1         0     0         0
# 2        99    99         0
# 3         0     0         0
# 4         0     0         0
#
# [5 rows x 68 columns]

# %%
# Grabbing the fourth of 5 files
distract_2013_df = pd.read_csv(filepath2013 + 'DISTRACT.CSV')
distract_2013_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  MDRDSTRD
# 0      1    10001       1         0
# 1      1    10002       1         0
# 2      1    10002       2         0
# 3      1    10003       1         0
# 4      1    10004       1        96

# %%
# Grabbing the 5th of 5 files
violation_2013_df = pd.read_csv(filepath2013+'VIOLATN.CSV')
violation_2013_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  MVIOLATN
# 0      1    10001       1         0
# 1      1    10002       1         0
# 2      1    10002       2         0
# 3      1    10003       1         0
# 4      1    10004       1         0

# %%
# Slimming the tables to jsut the columns we need
accidents_2013_df = accidents_2013_df[['STATE', 'ST_CASE', 'VE_TOTAL', 'PEDS', 'PERSONS', 'COUNTY', 'MONTH', 'DAY_WEEK', 'YEAR', 'HOUR', 'ROAD_FNC', 'ROUTE', 'LATITUDE', 'LONGITUD', 'HARM_EV', 'MAN_COLL', 'RELJCT2', 'TYP_INT', 'REL_ROAD', 'WRK_ZONE', 'LGT_COND', 'WEATHER', 'SCH_BUS', 'FATALS', 'DRUNK_DR']]
accidents_2013_df.head()
# Out:
#    STATE  ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  \
# 0      1    10001         1     0        8     115      1         1  2013
# 1      1    10002         2     0        2      55      1         5  2013
# 2      1    10003         1     0        1      89      1         1  2013
# 3      1    10004         1     0        3      73      1         1  2013
# 4      1    10005         2     0        3     125      1         1  2013
#
#    HOUR  ...  MAN_COLL  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# 0     0  ...         0        1        1         4         0         2
# 1    21  ...         6        2        2         1         0         3
# 2    11  ...         0        1        1         4         0         1
# 3    12  ...         0        1        1         4         0         1
# 4    18  ...         1       18        1         1         0         3
#
#    WEATHER  SCH_BUS  FATALS  DRUNK_DR
# 0       10        0       2         0
# 1       10        0       1         0
# 2       10        0       1         0
# 3        1        0       2         0
# 4        1        0       1         0
#
# [5 rows x 25 columns]

# %%
# Filtering to just accidents in Oregon 
accidents_2013_df = accidents_2013_df.loc[accidents_2013_df['STATE'] == 41]
accidents_2013_df
# Out:
#        STATE  ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  \
# 21696     41   410001         2     0        2      33      1         3  2013
# 21697     41   410002         1     1        1       3      1         3  2013
# 21698     41   410003         1     0        4      51      1         4  2013
# 21699     41   410004         1     0        1      33      1         6  2013
# 21700     41   410006         1     0        1      19      1         5  2013
# ...      ...      ...       ...   ...      ...     ...    ...       ...   ...
# 21983     41   410293         1     1        1      11     10         5  2013
# 21984     41   410294         1     2        1      33     10         4  2013
# 21985     41   410295         1     0        7      51     11         5  2013
# 21986     41   410296         1     0        2      11     11         6  2013
# 21987     41   410297         2     0        2      39     12         2  2013
#
#        HOUR  ...  MAN_COLL  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# 21696    15  ...         6        2        2         1         0         1
# 21697    12  ...         0        1        1         1         0         1
# 21698     6  ...         0        1        1         4         0         3
# 21699    21  ...         0        1        1         4         0         2
# 21700    11  ...         0        1        1         4         0         1
# ...     ...  ...       ...      ...      ...       ...       ...       ...
# 21983    15  ...         0        3        2         1         0         1
# 21984     0  ...         0        1        1         1         0         3
# 21985    19  ...         0        1        1         4         0         2
# 21986    99  ...         0        1        1         4         0         9
# 21987     8  ...        98        2        2         1         0         1
#
#        WEATHER  SCH_BUS  FATALS  DRUNK_DR
# 21696        1        0       1         0
# 21697       10        0       1         0
# 21698        2        0       1         1
# 21699        5        0       1         1
# 21700        4        0       1         0
# ...        ...      ...     ...       ...
# 21983       98        0       1         0
# 21984        1        0       2         0
# 21985       98        0       1         1
# 21986       98        0       1         0
# 21987       98        0       1         0
#
# [292 rows x 25 columns]

# %%
# Slimming to just the columns we need
vehicle_2013_df = vehicle_2013_df[['STATE', 'ST_CASE', 'VEH_NO', 'REG_STAT', 'BODY_TYP', 'TRAV_SP', 'DR_DRINK', 'PREV_ACC', 'PREV_DWI', 'PREV_SPD', 'SPEEDREL', 'VSPD_LIM', 'ACC_TYPE']]
vehicle_2013_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  REG_STAT  BODY_TYP  TRAV_SP  DR_DRINK  PREV_ACC  \
# 0      1    10001       1         1        16       70         0         0
# 1      1    10002       1         1        63       65         0         0
# 2      1    10002       2         1        31      998         0         0
# 3      1    10003       1         1         4      999         0         0
# 4      1    10004       1         1        31       69         0         0
#
#    PREV_DWI  PREV_SPD  SPEEDREL  VSPD_LIM  ACC_TYPE
# 0         0         0         0        70         7
# 1         0         0         0        65        88
# 2         0         1         0        98        89
# 3         0         0         0        40         1
# 4         0         0         3        40         7

# %%
# Filtering to just the accidents in Oregon
vehicle_2013_df = vehicle_2013_df.loc[vehicle_2013_df['STATE'] == 41]
vehicle_2013_df.head()
# Out:
#        STATE  ST_CASE  VEH_NO  REG_STAT  BODY_TYP  TRAV_SP  DR_DRINK  \
# 32319     41   410001       1        41        14      998         0
# 32320     41   410001       2        41        80      998         0
# 32321     41   410002       1        41         4      998         0
# 32322     41   410003       1        48        40       68         1
# 32323     41   410004       1        41         2      998         1
#
#        PREV_ACC  PREV_DWI  PREV_SPD  SPEEDREL  VSPD_LIM  ACC_TYPE
# 32319         0         0         1         0        45        68
# 32320         0         0         0         0        45        69
# 32321         0         0         0         9        55        13
# 32322        99        99        99         3        35         6
# 32323         1         0         0         4        55         6

# %%
# Slimming to just the columns we need
person_2013_df = person_2013_df[['STATE', 'ST_CASE', 'VEH_NO', 'PER_NO', 'AGE', 'SEX', 'PER_TYP', 'REST_USE', 'REST_MIS', 'DRUGS', 'DOA']]
person_2013_df.head()
# Out:
#    STATE  ST_CASE  VEH_NO  PER_NO  AGE  SEX  PER_TYP  REST_USE  REST_MIS  \
# 0      1    10001       1       1   28    2        1         3         0
# 1      1    10001       1       2   28    1        2         7         0
# 2      1    10001       1       3   27    1        2         3         0
# 3      1    10001       1       4  999    1        2        10         0
# 4      1    10001       1       5   47    2        2         7         0
#
#    DRUGS  DOA
# 0      0    0
# 1      8    0
# 2      8    7
# 3      8    0
# 4      8    0

# %%
# Filtering to just the accidents in Oregon
person_2013_df = person_2013_df.loc[person_2013_df['STATE'] == 41]
person_2013_df
# Out:
#        STATE  ST_CASE  VEH_NO  PER_NO  AGE  SEX  PER_TYP  REST_USE  REST_MIS  \
# 53541     41   410001       1       1   70    2        1         3         0
# 53542     41   410001       2       1   51    1        1         5         0
# 53543     41   410002       0       1   89    2        5        96         8
# 53544     41   410002       1       1   65    2        1         3         0
# 53545     41   410003       1       1   39    1        1        98         0
# ...      ...      ...     ...     ...  ...  ...      ...       ...       ...
# 54234     41   410295       1       7    7    1        2        98         0
# 54235     41   410296       1       1   17    1        1        99         0
# 54236     41   410296       1       2   24    1        2        99         0
# 54237     41   410297       1       1   83    1        1        98         0
# 54238     41   410297       2       1   62    2        1         3         0
#
#        DRUGS  DOA
# 53541      9    0
# 53542      9    0
# 53543      9    7
# 53544      0    0
# 53545      8    0
# ...      ...  ...
# 54234      8    0
# 54235      9    0
# 54236      8    7
# 54237      8    0
# 54238      8    0
#
# [698 rows x 11 columns]

# %%
# Filtering to just the accidents in Oregon
distract_2013_df = distract_2013_df.loc[distract_2013_df['STATE'] == 41]
distract_2013_df
# Out:
#        STATE  ST_CASE  VEH_NO  MDRDSTRD
# 32335     41   410001       1        96
# 32336     41   410001       2        96
# 32337     41   410002       1         0
# 32338     41   410003       1        96
# 32339     41   410004       1        96
# ...      ...      ...     ...       ...
# 32751     41   410294       1        96
# 32752     41   410295       1        96
# 32753     41   410296       1        96
# 32754     41   410297       1        96
# 32755     41   410297       2        96
#
# [421 rows x 4 columns]

# %%
# Filtering to just those in Oregon
violation_2013_df = violation_2013_df.loc[violation_2013_df['STATE'] == 41]
violation_2013_df
# Out:
#        STATE  ST_CASE  VEH_NO  MVIOLATN
# 34385     41   410001       1         2
# 34386     41   410001       2         0
# 34387     41   410002       1         0
# 34388     41   410003       1         1
# 34389     41   410003       1         2
# ...      ...      ...     ...       ...
# 34852     41   410295       1         2
# 34853     41   410295       1        11
# 34854     41   410296       1         1
# 34855     41   410297       1        99
# 34856     41   410297       2        99
#
# [472 rows x 4 columns]

# %%
# Re-indexing the different tables to make joining them possible
reindex_dis = distract_2013_df.set_index(['ST_CASE', 'VEH_NO']).drop('STATE', axis=1)
reindex_dis
# Out:
#                 MDRDSTRD
# ST_CASE VEH_NO
# 410001  1             96
#         2             96
# 410002  1              0
# 410003  1             96
# 410004  1             96
# ...                  ...
# 410294  1             96
# 410295  1             96
# 410296  1             96
# 410297  1             96
#         2             96
#
# [421 rows x 1 columns]

# %%
# Re-indexing vehicles
reindex_veh = vehicle_2013_df.set_index(['ST_CASE', 'VEH_NO']).drop('STATE', axis=1)
reindex_veh
# Out:
#                 REG_STAT  BODY_TYP  TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  \
# ST_CASE VEH_NO
# 410001  1             41        14      998         0         0         0
#         2             41        80      998         0         0         0
# 410002  1             41         4      998         0         0         0
# 410003  1             48        40       68         1        99        99
# 410004  1             41         2      998         1         1         0
# ...                  ...       ...      ...       ...       ...       ...
# 410294  1             99        99      998         0        99        99
# 410295  1             99        99      998         1         0         0
# 410296  1             41        14      998         0         0         0
# 410297  1             99        99      998         0         0         0
#         2             99        99      998         0         0         0
#
#                 PREV_SPD  SPEEDREL  VSPD_LIM  ACC_TYPE
# ST_CASE VEH_NO
# 410001  1              1         0        45        68
#         2              0         0        45        69
# 410002  1              0         9        55        13
# 410003  1             99         3        35         6
# 410004  1              0         4        55         6
# ...                  ...       ...       ...       ...
# 410294  1             99         9        45        13
# 410295  1              0         9        60         2
# 410296  1              0         4        98         1
# 410297  1              0         9        98        99
#         2              0         9        98        99
#
# [421 rows x 10 columns]

# %%
# Re-indexing violation table
reindex_vio = violation_2013_df.set_index(['ST_CASE', 'VEH_NO']).drop('STATE', axis=1)
reindex_vio
# Out:
#                 MVIOLATN
# ST_CASE VEH_NO
# 410001  1              2
#         2              0
# 410002  1              0
# 410003  1              1
#         1              2
# ...                  ...
# 410295  1              2
#         1             11
# 410296  1              1
# 410297  1             99
#         2             99
#
# [472 rows x 1 columns]

# %%
# Re-indexing person table
person_reindex = person_2013_df.set_index(['ST_CASE', 'VEH_NO', 'PER_NO']).drop('STATE', axis=1)
person_reindex
# Out:
#                        AGE  SEX  PER_TYP  REST_USE  REST_MIS  DRUGS  DOA
# ST_CASE VEH_NO PER_NO
# 410001  1      1        70    2        1         3         0      9    0
#         2      1        51    1        1         5         0      9    0
# 410002  0      1        89    2        5        96         8      9    7
#         1      1        65    2        1         3         0      0    0
# 410003  1      1        39    1        1        98         0      8    0
# ...                    ...  ...      ...       ...       ...    ...  ...
# 410295  1      7         7    1        2        98         0      8    0
# 410296  1      1        17    1        1        99         0      9    0
#                2        24    1        2        99         0      8    7
# 410297  1      1        83    1        1        98         0      8    0
#         2      1        62    2        1         3         0      8    0
#
# [698 rows x 7 columns]

# %%
# Starting the process of merging the rows down to just 'ST_CASE' index, starting by dropping unneeded columns
person_reindex = person_reindex.drop(['PER_TYP', 'REST_USE', 'DOA'], axis=1)
person_reindex[0:10]
# Out:
#                        AGE  SEX  REST_MIS  DRUGS
# ST_CASE VEH_NO PER_NO
# 410001  1      1        70    2         0      9
#         2      1        51    1         0      9
# 410002  0      1        89    2         8      9
#         1      1        65    2         0      0
# 410003  1      1        39    1         0      8
#                2        34    1         0      0
#                3        20    1         0      0
#                4        39    1         0      8
# 410004  1      1        36    1         0      8
# 410006  1      1        71    1         0      9

# %%
# Now switching to accident_df, as that will be the table everything merges to, adding an 'AGE' column
accidents_2013_df['AGE'] = 0
accidents_2013_df.head()
# Out:
#        STATE  ST_CASE  VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  \
# 21696     41   410001         2     0        2      33      1         3  2013
# 21697     41   410002         1     1        1       3      1         3  2013
# 21698     41   410003         1     0        4      51      1         4  2013
# 21699     41   410004         1     0        1      33      1         6  2013
# 21700     41   410006         1     0        1      19      1         5  2013
#
#        HOUR  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  WEATHER  \
# 21696    15  ...        2        2         1         0         1        1
# 21697    12  ...        1        1         1         0         1       10
# 21698     6  ...        1        1         4         0         3        2
# 21699    21  ...        1        1         4         0         2        5
# 21700    11  ...        1        1         4         0         1        4
#
#        SCH_BUS  FATALS  DRUNK_DR  AGE
# 21696        0       1         0    0
# 21697        0       1         0    0
# 21698        0       1         1    0
# 21699        0       1         1    0
# 21700        0       1         0    0
#
# [5 rows x 26 columns]

# %%
# Re-indexing to st_case
accidents_reindex = accidents_2013_df.set_index('ST_CASE').drop('STATE', axis=1)
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# ST_CASE                   ...
# 410001         13      2  ...        2        2         1         0         1
# 410002          4      4  ...        1        1         1         0         1
# 410003         16      6  ...        1        1         4         0         3
# 410004          4      3  ...        1        1         4         0         2
# 410006          1      1  ...        1        1         4         0         1
# ...           ...    ...  ...      ...      ...       ...       ...       ...
# 410293          4      6  ...        3        2         1         0         1
# 410294          2      2  ...        1        1         1         0         3
# 410295         11      1  ...        1        1         4         0         2
# 410296          4      4  ...        1        1         4         0         9
# 410297         14      6  ...        2        2         1         0         1
#
#          WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE
# ST_CASE
# 410001         1        0       1         0    0
# 410002        10        0       1         0    0
# 410003         2        0       1         1    0
# 410004         5        0       1         1    0
# 410006         4        0       1         0    0
# ...          ...      ...     ...       ...  ...
# 410293        98        0       1         0    0
# 410294         1        0       2         0    0
# 410295        98        0       1         1    0
# 410296        98        0       1         0    0
# 410297        98        0       1         0    0
#
# [292 rows x 24 columns]

# %%
# Adding average age to accident table
prev_st = 0

for index in person_reindex.index:
    st_case = index[0]
    
    if st_case != prev_st:
        ave_age = person_reindex.loc[st_case]['AGE'].mean()
        
        # unknown ages are listed as 999
        if ave_age > 125:
            ave_age = 999
        
        accidents_reindex.at[st_case, 'AGE'] = ave_age
        
        prev_st = st_case
        
    else:
        prev_st = st_case
        
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  RELJCT2  TYP_INT  REL_ROAD  WRK_ZONE  LGT_COND  \
# ST_CASE                   ...
# 410001         13      2  ...        2        2         1         0         1
# 410002          4      4  ...        1        1         1         0         1
# 410003         16      6  ...        1        1         4         0         3
# 410004          4      3  ...        1        1         4         0         2
# 410006          1      1  ...        1        1         4         0         1
# ...           ...    ...  ...      ...      ...       ...       ...       ...
# 410293          4      6  ...        3        2         1         0         1
# 410294          2      2  ...        1        1         1         0         3
# 410295         11      1  ...        1        1         4         0         2
# 410296          4      4  ...        1        1         4         0         9
# 410297         14      6  ...        2        2         1         0         1
#
#          WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE
# ST_CASE
# 410001         1        0       1         0   60
# 410002        10        0       1         0   77
# 410003         2        0       1         1   33
# 410004         5        0       1         1   36
# 410006         4        0       1         0   71
# ...          ...      ...     ...       ...  ...
# 410293        98        0       1         0   75
# 410294         1        0       2         0  999
# 410295        98        0       1         1  999
# 410296        98        0       1         0   20
# 410297        98        0       1         0   72
#
# [292 rows x 24 columns]

# %%
# Adding gender columns, will be a count for each accident
accidents_reindex['SEX_1'] = 0
accidents_reindex['SEX_2'] = 0
accidents_reindex['SEX_8'] = 0
accidents_reindex['SEX_9'] = 0

# %%
# Setting gender columns in accidents_df
gender_1 = 0
gender_2 = 0
gender_8 = 0
gender_9 = 0

prev_case = 410001

for index in person_reindex.index:
    st_case = index[0]
    
    if st_case == prev_case:
    
        gender = person_reindex.loc[index]['SEX']
    
        if gender == 1:
            gender_1 += 1
    
        elif gender == 2:
            gender_2 += 1
        
        elif gender == 8:
            gender_8 += 1
        
        elif gender == 9:
            gender_9 += 1
            
        accidents_reindex.at[st_case, 'SEX_1'] = gender_1
        accidents_reindex.at[st_case, 'SEX_2'] = gender_2
        accidents_reindex.at[st_case, 'SEX_8'] = gender_8
        accidents_reindex.at[st_case, 'SEX_9'] = gender_9
        
        prev_case = st_case
            
    elif st_case != prev_case:
        
        gender_1 = 0
        gender_2 = 0
        gender_8 = 0
        gender_9 = 0
        
        gender = person_reindex.loc[index]['SEX']
    
        if gender == 1:
            gender_1 += 1
    
        elif gender == 2:
            gender_2 += 1
        
        elif gender == 8:
            gender_8 += 1
        
        elif gender == 9:
            gender_9 += 1
            
        accidents_reindex.at[st_case, 'SEX_1'] = gender_1
        accidents_reindex.at[st_case, 'SEX_2'] = gender_2
        accidents_reindex.at[st_case, 'SEX_8'] = gender_8
        accidents_reindex.at[st_case, 'SEX_9'] = gender_9
        
        prev_case = st_case
        

accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  LGT_COND  WEATHER  SCH_BUS  FATALS  DRUNK_DR  \
# ST_CASE                   ...
# 410001         13      2  ...         1        1        0       1         0
# 410002          4      4  ...         1       10        0       1         0
# 410003         16      6  ...         3        2        0       1         1
# 410004          4      3  ...         2        5        0       1         1
# 410006          1      1  ...         1        4        0       1         0
# ...           ...    ...  ...       ...      ...      ...     ...       ...
# 410293          4      6  ...         1       98        0       1         0
# 410294          2      2  ...         3        1        0       2         0
# 410295         11      1  ...         2       98        0       1         1
# 410296          4      4  ...         9       98        0       1         0
# 410297         14      6  ...         1       98        0       1         0
#
#          AGE  SEX_1  SEX_2  SEX_8  SEX_9
# ST_CASE
# 410001    60      1      1      0      0
# 410002    77      0      2      0      0
# 410003    33      4      0      0      0
# 410004    36      1      0      0      0
# 410006    71      1      0      0      0
# ...      ...    ...    ...    ...    ...
# 410293    75      2      0      0      0
# 410294   999      2      0      0      1
# 410295   999      1      2      0      4
# 410296    20      2      0      0      0
# 410297    72      1      1      0      0
#
# [292 rows x 28 columns]

# %%
# Set the retstraint misuse column in accidents
accidents_reindex['REST_MIS'] = 0

# %%
# This one is a simple yes/no for the column value
for index in person_reindex.index:
    st_case = index[0]
            
    if person_reindex.loc[index]['REST_MIS'] == 1:
        accidents_reindex.at[st_case, 'REST_MIS'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  WEATHER  SCH_BUS  FATALS  DRUNK_DR  AGE  SEX_1  \
# ST_CASE                   ...
# 410001         13      2  ...        1        0       1         0   60      1
# 410002          4      4  ...       10        0       1         0   77      0
# 410003         16      6  ...        2        0       1         1   33      4
# 410004          4      3  ...        5        0       1         1   36      1
# 410006          1      1  ...        4        0       1         0   71      1
# ...           ...    ...  ...      ...      ...     ...       ...  ...    ...
# 410293          4      6  ...       98        0       1         0   75      2
# 410294          2      2  ...        1        0       2         0  999      2
# 410295         11      1  ...       98        0       1         1  999      1
# 410296          4      4  ...       98        0       1         0   20      2
# 410297         14      6  ...       98        0       1         0   72      1
#
#          SEX_2  SEX_8  SEX_9  REST_MIS
# ST_CASE
# 410001       1      0      0         0
# 410002       2      0      0         0
# 410003       0      0      0         0
# 410004       0      0      0         0
# 410006       0      0      0         0
# ...        ...    ...    ...       ...
# 410293       0      0      0         0
# 410294       0      0      1         0
# 410295       2      0      4         0
# 410296       0      0      0         0
# 410297       1      0      0         0
#
# [292 rows x 29 columns]

# %%
# set the drugs column in accidents
accidents_reindex['DRUGS'] = 0

# %%
for index in person_reindex.index:
    st_case = index[0]
            
    if person_reindex.loc[index]['DRUGS'] == 1:
        accidents_reindex.at[st_case, 'DRUGS'] = 1
    
    elif (person_reindex.loc[index]['DRUGS'] == 8) or (person_reindex.loc[index]['DRUGS'] == 9):
        accidents_reindex.at[st_case, 'DRUGS'] = 9
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  SCH_BUS  FATALS  DRUNK_DR  AGE  SEX_1  SEX_2  \
# ST_CASE                   ...
# 410001         13      2  ...        0       1         0   60      1      1
# 410002          4      4  ...        0       1         0   77      0      2
# 410003         16      6  ...        0       1         1   33      4      0
# 410004          4      3  ...        0       1         1   36      1      0
# 410006          1      1  ...        0       1         0   71      1      0
# ...           ...    ...  ...      ...     ...       ...  ...    ...    ...
# 410293          4      6  ...        0       1         0   75      2      0
# 410294          2      2  ...        0       2         0  999      2      0
# 410295         11      1  ...        0       1         1  999      1      2
# 410296          4      4  ...        0       1         0   20      2      0
# 410297         14      6  ...        0       1         0   72      1      1
#
#          SEX_8  SEX_9  REST_MIS  DRUGS
# ST_CASE
# 410001       0      0         0      9
# 410002       0      0         0      9
# 410003       0      0         0      9
# 410004       0      0         0      9
# 410006       0      0         0      9
# ...        ...    ...       ...    ...
# 410293       0      0         0      9
# 410294       0      1         0      9
# 410295       0      4         0      9
# 410296       0      0         0      9
# 410297       0      0         0      9
#
# [292 rows x 30 columns]

# %%
# Setting body_type columns in accidents
accidents_reindex['BT_Sedan'] = 0
accidents_reindex['BT_Pickup'] = 0
accidents_reindex['BT_SUV_Van'] = 0
accidents_reindex['BT_Motorcyle'] = 0
accidents_reindex['BT_Truck'] = 0
accidents_reindex['BT_Bus'] = 0
accidents_reindex['BT_Unknown_Other'] = 0

# %%
# Similar to gender column, adding the types together for each accident
bt_sedan = 0
bt_pickup = 0
bt_suv = 0
bt_motor = 0
bt_truck = 0
bt_bus = 0
bt_unknown = 0


prev_case = 410001

for index in reindex_veh.index:
    st_case = index[0]
    
    if st_case == prev_case:
    
        bt = reindex_veh.loc[index]['BODY_TYP']
    
        if bt <= 6:
            bt_sedan += 1
    
        elif (bt == 10) or (bt == 30) or (bt == 31) or (bt == 67):
            bt_pickup += 1
        
        elif (bt == 14) or (bt == 15) or (bt == 16) or (bt == 20) or (bt == 21):
            bt_suv += 1
        
        elif (bt == 80) or (bt == 81):
            bt_motor += 1
        
        elif (bt == 61) or (bt == 63) or (bt == 64) or (bt == 65) or (bt == 66):
            bt_truck += 1
            
        elif (bt == 50) or (bt == 52) or (bt == 55):
            bt_bus += 1
            
        elif (bt == 49) or (bt == 90) or (bt == 99):
            bt_unknown += 1
            
        accidents_reindex.at[st_case, 'BT_Sedan'] = bt_sedan
        accidents_reindex.at[st_case, 'BT_Pickup'] = bt_pickup
        accidents_reindex.at[st_case, 'BT_SUV_Van'] = bt_suv
        accidents_reindex.at[st_case, 'BT_Motorcycle'] = bt_motor
        accidents_reindex.at[st_case, 'BT_Truck'] = bt_truck
        accidents_reindex.at[st_case, 'BT_Bus'] = bt_bus
        accidents_reindex.at[st_case, 'BT_Unknown_Other'] = bt_unknown
        
        prev_case = st_case
            
    elif st_case != prev_case:
        
        bt_sedan = 0
        bt_pickup = 0
        bt_suv = 0
        bt_motor = 0
        bt_truck = 0
        bt_bus = 0
        bt_unknown = 0
        
        bt = reindex_veh.loc[index]['BODY_TYP']
    
        if bt <= 6:
            bt_sedan += 1
    
        elif (bt == 10) or (bt == 30) or (bt == 31) or (bt == 67):
            bt_pickup += 1
        
        elif (bt == 14) or (bt == 15) or (bt == 16) or (bt == 20) or (bt == 21):
            bt_suv += 1
        
        elif (bt == 80) or (bt == 81):
            bt_motor += 1
        
        elif (bt == 61) or (bt == 63) or (bt == 64) or (bt == 65) or (bt == 66):
            bt_truck += 1
            
        elif (bt == 50) or (bt == 52) or (bt == 55):
            bt_bus += 1
            
        elif (bt == 49) or (bt == 90) or (bt == 99):
            bt_unknown += 1
            
        accidents_reindex.at[st_case, 'BT_Sedan'] = bt_sedan
        accidents_reindex.at[st_case, 'BT_Pickup'] = bt_pickup
        accidents_reindex.at[st_case, 'BT_SUV_Van'] = bt_suv
        accidents_reindex.at[st_case, 'BT_Motorcycle'] = bt_motor
        accidents_reindex.at[st_case, 'BT_Truck'] = bt_truck
        accidents_reindex.at[st_case, 'BT_Bus'] = bt_bus
        accidents_reindex.at[st_case, 'BT_Unknown_Other'] = bt_unknown
        
        prev_case = st_case
        

accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  REST_MIS  DRUGS  BT_Sedan  BT_Pickup  \
# ST_CASE                   ...
# 410001         13      2  ...         0      9         0          0
# 410002          4      4  ...         0      9         1          0
# 410003         16      6  ...         0      9         0          0
# 410004          4      3  ...         0      9         1          0
# 410006          1      1  ...         0      9         0          0
# ...           ...    ...  ...       ...    ...       ...        ...
# 410293          4      6  ...         0      9         0          1
# 410294          2      2  ...         0      9         0          0
# 410295         11      1  ...         0      9         0          0
# 410296          4      4  ...         0      9         0          0
# 410297         14      6  ...         0      9         0          0
#
#          BT_SUV_Van  BT_Motorcyle  BT_Truck  BT_Bus  BT_Unknown_Other  \
# ST_CASE
# 410001            1             0         0       0                 0
# 410002            0             0         0       0                 0
# 410003            0             0         0       0                 0
# 410004            0             0         0       0                 0
# 410006            0             0         1       0                 0
# ...             ...           ...       ...     ...               ...
# 410293            0             0         0       0                 0
# 410294            0             0         0       0                 1
# 410295            0             0         0       0                 1
# 410296            1             0         0       0                 0
# 410297            0             0         0       0                 2
#
#          BT_Motorcycle
# ST_CASE
# 410001             1.0
# 410002             0.0
# 410003             0.0
# 410004             0.0
# 410006             0.0
# ...                ...
# 410293             0.0
# 410294             0.0
# 410295             0.0
# 410296             0.0
# 410297             0.0
#
# [292 rows x 38 columns]

# %%
# Adding registration state (out of state true/false) to accidents
accidents_reindex['OOS_REG'] = 0

# %%
for index in reindex_veh.index:
    st_case = index[0]
            
    if reindex_veh.loc[index]['REG_STAT'] == 99:
        accidents_reindex.at[st_case, 'OOS_REG'] = 99
    
    elif reindex_veh.loc[index]['REG_STAT'] != 41:
        accidents_reindex.at[st_case, 'OOS_REG'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  DRUGS  BT_Sedan  BT_Pickup  BT_SUV_Van  \
# ST_CASE                   ...
# 410001         13      2  ...      9         0          0           1
# 410002          4      4  ...      9         1          0           0
# 410003         16      6  ...      9         0          0           0
# 410004          4      3  ...      9         1          0           0
# 410006          1      1  ...      9         0          0           0
# ...           ...    ...  ...    ...       ...        ...         ...
# 410293          4      6  ...      9         0          1           0
# 410294          2      2  ...      9         0          0           0
# 410295         11      1  ...      9         0          0           0
# 410296          4      4  ...      9         0          0           1
# 410297         14      6  ...      9         0          0           0
#
#          BT_Motorcyle  BT_Truck  BT_Bus  BT_Unknown_Other  BT_Motorcycle  \
# ST_CASE
# 410001              0         0       0                 0            1.0
# 410002              0         0       0                 0            0.0
# 410003              0         0       0                 0            0.0
# 410004              0         0       0                 0            0.0
# 410006              0         1       0                 0            0.0
# ...               ...       ...     ...               ...            ...
# 410293              0         0       0                 0            0.0
# 410294              0         0       0                 1            0.0
# 410295              0         0       0                 1            0.0
# 410296              0         0       0                 0            0.0
# 410297              0         0       0                 2            0.0
#
#          OOS_REG
# ST_CASE
# 410001         0
# 410002         0
# 410003         1
# 410004         0
# 410006         1
# ...          ...
# 410293         0
# 410294        99
# 410295        99
# 410296         0
# 410297        99
#
# [292 rows x 39 columns]

# %%
# Adding Travel speed to accidents
accidents_reindex['TRAV_SP'] = 0

# %%
speed = 0

for index in reindex_veh.index:
    st_case = index[0]
    
    if reindex_veh.loc[index]['TRAV_SP'] > 151:
        accidents_reindex.at[st_case, 'TRAV_SP'] = 999
        
    else:
        new_speed = reindex_veh.loc[index]['TRAV_SP']
        
        if new_speed > speed:
            accidents_reindex.at[st_case, 'TRAV_SP'] = new_speed
            speed = new_speed

        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_Sedan  BT_Pickup  BT_SUV_Van  BT_Motorcyle  \
# ST_CASE                   ...
# 410001         13      2  ...         0          0           1             0
# 410002          4      4  ...         1          0           0             0
# 410003         16      6  ...         0          0           0             0
# 410004          4      3  ...         1          0           0             0
# 410006          1      1  ...         0          0           0             0
# ...           ...    ...  ...       ...        ...         ...           ...
# 410293          4      6  ...         0          1           0             0
# 410294          2      2  ...         0          0           0             0
# 410295         11      1  ...         0          0           0             0
# 410296          4      4  ...         0          0           1             0
# 410297         14      6  ...         0          0           0             0
#
#          BT_Truck  BT_Bus  BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP
# ST_CASE
# 410001          0       0                 0            1.0        0      999
# 410002          0       0                 0            0.0        0      999
# 410003          0       0                 0            0.0        1       68
# 410004          0       0                 0            0.0        0      999
# 410006          1       0                 0            0.0        1      999
# ...           ...     ...               ...            ...      ...      ...
# 410293          0       0                 0            0.0        0      999
# 410294          0       0                 1            0.0       99      999
# 410295          0       0                 1            0.0       99      999
# 410296          0       0                 0            0.0        0      999
# 410297          0       0                 2            0.0       99      999
#
# [292 rows x 40 columns]

# %%
# Adding dr_drink to accidents
accidents_reindex['DR_DRINK'] = 0

# %%
for index in reindex_veh.index:
    st_case = index[0]
            
    if reindex_veh.loc[index]['DR_DRINK'] == 1:
        accidents_reindex.at[st_case, 'DR_DRINK'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_Pickup  BT_SUV_Van  BT_Motorcyle  BT_Truck  \
# ST_CASE                   ...
# 410001         13      2  ...          0           1             0         0
# 410002          4      4  ...          0           0             0         0
# 410003         16      6  ...          0           0             0         0
# 410004          4      3  ...          0           0             0         0
# 410006          1      1  ...          0           0             0         1
# ...           ...    ...  ...        ...         ...           ...       ...
# 410293          4      6  ...          1           0             0         0
# 410294          2      2  ...          0           0             0         0
# 410295         11      1  ...          0           0             0         0
# 410296          4      4  ...          0           1             0         0
# 410297         14      6  ...          0           0             0         0
#
#          BT_Bus  BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK
# ST_CASE
# 410001        0                 0            1.0        0      999         0
# 410002        0                 0            0.0        0      999         0
# 410003        0                 0            0.0        1       68         1
# 410004        0                 0            0.0        0      999         1
# 410006        0                 0            0.0        1      999         0
# ...         ...               ...            ...      ...      ...       ...
# 410293        0                 0            0.0        0      999         0
# 410294        0                 1            0.0       99      999         0
# 410295        0                 1            0.0       99      999         1
# 410296        0                 0            0.0        0      999         0
# 410297        0                 2            0.0       99      999         0
#
# [292 rows x 41 columns]

# %%
# Adding prev_acc to accidents
accidents_reindex['PREV_ACC'] = 0

# %%
acc_count = 0
prev_case = 410001

for index in reindex_veh.index:
    st_case = index[0]
    
    if st_case == prev_case:
        
        if reindex_veh.loc[index]['PREV_ACC'] > 97:
            accidents_reindex.at[st_case, 'PREV_ACC'] = 99
        else:
            acc_count += reindex_veh.loc[index]['PREV_ACC']
            
        accidents_reindex.at[st_case, 'PREV_ACC'] = acc_count
        
        prev_case = st_case
    
    elif st_case != prev_case:
        acc_count = 0
        
        if reindex_veh.loc[index]['PREV_ACC'] > 97:
            accidents_reindex.at[st_case, 'PREV_ACC'] = 99
        else:
            acc_count += reindex_veh.loc[index]['PREV_ACC']
            
        accidents_reindex.at[st_case, 'PREV_ACC'] = acc_count
        
        prev_case = st_case
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_SUV_Van  BT_Motorcyle  BT_Truck  BT_Bus  \
# ST_CASE                   ...
# 410001         13      2  ...           1             0         0       0
# 410002          4      4  ...           0             0         0       0
# 410003         16      6  ...           0             0         0       0
# 410004          4      3  ...           0             0         0       0
# 410006          1      1  ...           0             0         1       0
# ...           ...    ...  ...         ...           ...       ...     ...
# 410293          4      6  ...           0             0         0       0
# 410294          2      2  ...           0             0         0       0
# 410295         11      1  ...           0             0         0       0
# 410296          4      4  ...           1             0         0       0
# 410297         14      6  ...           0             0         0       0
#
#          BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK  PREV_ACC
# ST_CASE
# 410001                  0            1.0        0      999         0         0
# 410002                  0            0.0        0      999         0         0
# 410003                  0            0.0        1       68         1         0
# 410004                  0            0.0        0      999         1         1
# 410006                  0            0.0        1      999         0         0
# ...                   ...            ...      ...      ...       ...       ...
# 410293                  0            0.0        0      999         0         0
# 410294                  1            0.0       99      999         0         0
# 410295                  1            0.0       99      999         1         0
# 410296                  0            0.0        0      999         0         0
# 410297                  2            0.0       99      999         0         0
#
# [292 rows x 42 columns]

# %%
# Adding prev_dwi to accidents
accidents_reindex['PREV_DWI'] = 0

# %%
dwi_count = 0
prev_case = 410001

for index in reindex_veh.index:
    st_case = index[0]
    
    if st_case == prev_case:
        
        if reindex_veh.loc[index]['PREV_DWI'] > 97:
            accidents_reindex.at[st_case, 'PREV_DWI'] = 99
        else:
            dwi_count += reindex_veh.loc[index]['PREV_DWI']
            
        accidents_reindex.at[st_case, 'PREV_DWI'] = dwi_count
        
        prev_case = st_case
    
    elif st_case != prev_case:
        dwi_count = 0
        
        if reindex_veh.loc[index]['PREV_DWI'] > 97:
            accidents_reindex.at[st_case, 'PREV_DWI'] = 99
        else:
            dwi_count += reindex_veh.loc[index]['PREV_DWI']
            
        accidents_reindex.at[st_case, 'PREV_DWI'] = dwi_count
        
        prev_case = st_case
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_Motorcyle  BT_Truck  BT_Bus  \
# ST_CASE                   ...
# 410001         13      2  ...             0         0       0
# 410002          4      4  ...             0         0       0
# 410003         16      6  ...             0         0       0
# 410004          4      3  ...             0         0       0
# 410006          1      1  ...             0         1       0
# ...           ...    ...  ...           ...       ...     ...
# 410293          4      6  ...             0         0       0
# 410294          2      2  ...             0         0       0
# 410295         11      1  ...             0         0       0
# 410296          4      4  ...             0         0       0
# 410297         14      6  ...             0         0       0
#
#          BT_Unknown_Other  BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK  \
# ST_CASE
# 410001                  0            1.0        0      999         0
# 410002                  0            0.0        0      999         0
# 410003                  0            0.0        1       68         1
# 410004                  0            0.0        0      999         1
# 410006                  0            0.0        1      999         0
# ...                   ...            ...      ...      ...       ...
# 410293                  0            0.0        0      999         0
# 410294                  1            0.0       99      999         0
# 410295                  1            0.0       99      999         1
# 410296                  0            0.0        0      999         0
# 410297                  2            0.0       99      999         0
#
#          PREV_ACC  PREV_DWI
# ST_CASE
# 410001          0         0
# 410002          0         0
# 410003          0         0
# 410004          1         0
# 410006          0         0
# ...           ...       ...
# 410293          0         0
# 410294          0         0
# 410295          0         0
# 410296          0         0
# 410297          0         0
#
# [292 rows x 43 columns]

# %%
# Adding prev_spd to accidents
accidents_reindex['PREV_SPD'] = 0

# %%
spd_count = 0
prev_case = 410001

for index in reindex_veh.index:
    st_case = index[0]
    
    if st_case == prev_case:
        
        if reindex_veh.loc[index]['PREV_SPD'] > 97:
            accidents_reindex.at[st_case, 'PREV_SPD'] = 99
        else:
            spd_count += reindex_veh.loc[index]['PREV_SPD']
            
        accidents_reindex.at[st_case, 'PREV_SPD'] = spd_count
        
        prev_case = st_case
    
    elif st_case != prev_case:
        spd_count = 0
        
        if reindex_veh.loc[index]['PREV_SPD'] > 97:
            accidents_reindex.at[st_case, 'PREV_SPD'] = 99
        else:
            spd_count += reindex_veh.loc[index]['PREV_SPD']
            
        accidents_reindex.at[st_case, 'PREV_SPD'] = spd_count
        
        prev_case = st_case
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_Truck  BT_Bus  BT_Unknown_Other  \
# ST_CASE                   ...
# 410001         13      2  ...         0       0                 0
# 410002          4      4  ...         0       0                 0
# 410003         16      6  ...         0       0                 0
# 410004          4      3  ...         0       0                 0
# 410006          1      1  ...         1       0                 0
# ...           ...    ...  ...       ...     ...               ...
# 410293          4      6  ...         0       0                 0
# 410294          2      2  ...         0       0                 1
# 410295         11      1  ...         0       0                 1
# 410296          4      4  ...         0       0                 0
# 410297         14      6  ...         0       0                 2
#
#          BT_Motorcycle  OOS_REG  TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  \
# ST_CASE
# 410001             1.0        0      999         0         0         0
# 410002             0.0        0      999         0         0         0
# 410003             0.0        1       68         1         0         0
# 410004             0.0        0      999         1         1         0
# 410006             0.0        1      999         0         0         0
# ...                ...      ...      ...       ...       ...       ...
# 410293             0.0        0      999         0         0         0
# 410294             0.0       99      999         0         0         0
# 410295             0.0       99      999         1         0         0
# 410296             0.0        0      999         0         0         0
# 410297             0.0       99      999         0         0         0
#
#          PREV_SPD
# ST_CASE
# 410001          1
# 410002          0
# 410003          0
# 410004          0
# 410006          0
# ...           ...
# 410293          0
# 410294          0
# 410295          0
# 410296          0
# 410297          0
#
# [292 rows x 44 columns]

# %%
# Adding speed_rel to accidents
accidents_reindex['SPEED_REL'] = 0

# %%
for index in reindex_veh.index:
    st_case = index[0]
            
    if reindex_veh.loc[index]['SPEEDREL'] > 5:
        accidents_reindex.at[st_case, 'SPEED_REL'] = 9
    
    elif reindex_veh.loc[index]['SPEEDREL'] > 0:
        accidents_reindex.at[st_case, 'SPEED_REL'] = 1
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_Bus  BT_Unknown_Other  BT_Motorcycle  \
# ST_CASE                   ...
# 410001         13      2  ...       0                 0            1.0
# 410002          4      4  ...       0                 0            0.0
# 410003         16      6  ...       0                 0            0.0
# 410004          4      3  ...       0                 0            0.0
# 410006          1      1  ...       0                 0            0.0
# ...           ...    ...  ...     ...               ...            ...
# 410293          4      6  ...       0                 0            0.0
# 410294          2      2  ...       0                 1            0.0
# 410295         11      1  ...       0                 1            0.0
# 410296          4      4  ...       0                 0            0.0
# 410297         14      6  ...       0                 2            0.0
#
#          OOS_REG  TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  PREV_SPD  SPEED_REL
# ST_CASE
# 410001         0      999         0         0         0         1          0
# 410002         0      999         0         0         0         0          9
# 410003         1       68         1         0         0         0          1
# 410004         0      999         1         1         0         0          1
# 410006         1      999         0         0         0         0          0
# ...          ...      ...       ...       ...       ...       ...        ...
# 410293         0      999         0         0         0         0          0
# 410294        99      999         0         0         0         0          9
# 410295        99      999         1         0         0         0          9
# 410296         0      999         0         0         0         0          1
# 410297        99      999         0         0         0         0          9
#
# [292 rows x 45 columns]

# %%
# Adding vspd_lim to accidents
accidents_reindex['VSPD_LIM'] = 0

# %%
speed = 0

for index in reindex_veh.index:
    st_case = index[0]
    
    if reindex_veh.loc[index]['VSPD_LIM'] > 95:
        accidents_reindex.at[st_case, 'VSPD_LIM'] = 99
        
    else:
        new_speed = reindex_veh.loc[index]['VSPD_LIM']
        
        if new_speed > speed:
            accidents_reindex.at[st_case, 'VSPD_LIM'] = new_speed
            speed = new_speed

        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  BT_Unknown_Other  BT_Motorcycle  OOS_REG  \
# ST_CASE                   ...
# 410001         13      2  ...                 0            1.0        0
# 410002          4      4  ...                 0            0.0        0
# 410003         16      6  ...                 0            0.0        1
# 410004          4      3  ...                 0            0.0        0
# 410006          1      1  ...                 0            0.0        1
# ...           ...    ...  ...               ...            ...      ...
# 410293          4      6  ...                 0            0.0        0
# 410294          2      2  ...                 1            0.0       99
# 410295         11      1  ...                 1            0.0       99
# 410296          4      4  ...                 0            0.0        0
# 410297         14      6  ...                 2            0.0       99
#
#          TRAV_SP  DR_DRINK  PREV_ACC  PREV_DWI  PREV_SPD  SPEED_REL  VSPD_LIM
# ST_CASE
# 410001       999         0         0         0         1          0        45
# 410002       999         0         0         0         0          9        55
# 410003        68         1         0         0         0          1         0
# 410004       999         1         1         0         0          1         0
# 410006       999         0         0         0         0          0         0
# ...          ...       ...       ...       ...       ...        ...       ...
# 410293       999         0         0         0         0          0         0
# 410294       999         0         0         0         0          9         0
# 410295       999         1         0         0         0          9         0
# 410296       999         0         0         0         0          1        99
# 410297       999         0         0         0         0          9        99
#
# [292 rows x 46 columns]

# %%
# Adding acc_type columns to accident
accidents_reindex['ACC_TYPE_A'] = 0
accidents_reindex['ACC_TYPE_B'] = 0
accidents_reindex['ACC_TYPE_C'] = 0
accidents_reindex['ACC_TYPE_D'] = 0
accidents_reindex['ACC_TYPE_E'] = 0
accidents_reindex['ACC_TYPE_F'] = 0
accidents_reindex['ACC_TYPE_G'] = 0
accidents_reindex['ACC_TYPE_H'] = 0
accidents_reindex['ACC_TYPE_I'] = 0
accidents_reindex['ACC_TYPE_J'] = 0
accidents_reindex['ACC_TYPE_K'] = 0
accidents_reindex['ACC_TYPE_L'] = 0
accidents_reindex['ACC_TYPE_M'] = 0

# %%
# Doing a binary for each accident type
type_a = 0
type_b = 0
type_c = 0
type_d = 0
type_e = 0
type_f = 0
type_g = 0
type_h = 0
type_i = 0
type_j = 0
type_k = 0
type_l = 0
type_m = 0

prev_case = 410001

for index in reindex_veh.index:
    st_case = index[0]
    
    if st_case == prev_case:
    
        acc_type = reindex_veh.loc[index]['ACC_TYPE']
    
        if acc_type <= 5:
            type_a = 1
    
        elif acc_type <= 10:
            type_b = 1
        
        elif acc_type <= 16:
            type_c = 1
        
        elif acc_type <= 33:
            type_d = 1
        
        elif acc_type <= 43:
            type_e = 1
            
        elif acc_type <= 49:
            type_f = 1
            
        elif acc_type <= 53:
            type_g = 1
            
        elif acc_type <= 63:
            type_h = 1
            
        elif acc_type <= 67:
            type_i = 1
            
        elif acc_type <= 75:
            type_j = 1
            
        elif acc_type <= 85:
            type_k = 1
            
        elif acc_type <= 91:
            type_l = 1
            
        elif acc_type <= 99:
            type_m = 1
            
        accidents_reindex.at[st_case, 'ACC_TYPE_A'] = type_a
        accidents_reindex.at[st_case, 'ACC_TYPE_B'] = type_b
        accidents_reindex.at[st_case, 'ACC_TYPE_C'] = type_c
        accidents_reindex.at[st_case, 'ACC_TYPE_D'] = type_d
        accidents_reindex.at[st_case, 'ACC_TYPE_E'] = type_e
        accidents_reindex.at[st_case, 'ACC_TYPE_F'] = type_f
        accidents_reindex.at[st_case, 'ACC_TYPE_G'] = type_g
        accidents_reindex.at[st_case, 'ACC_TYPE_H'] = type_h
        accidents_reindex.at[st_case, 'ACC_TYPE_I'] = type_i
        accidents_reindex.at[st_case, 'ACC_TYPE_J'] = type_j
        accidents_reindex.at[st_case, 'ACC_TYPE_K'] = type_k
        accidents_reindex.at[st_case, 'ACC_TYPE_L'] = type_l
        accidents_reindex.at[st_case, 'ACC_TYPE_M'] = type_m
        
        
        prev_case = st_case
            
    elif st_case != prev_case:
        
        type_a = 0
        type_b = 0
        type_c = 0
        type_d = 0
        type_e = 0
        type_f = 0
        type_g = 0
        type_h = 0
        type_i = 0
        type_j = 0
        type_k = 0
        type_l = 0
        type_m = 0

        acc_type = reindex_veh.loc[index]['ACC_TYPE']

        if acc_type <= 5:
            type_a = 1

        elif acc_type <= 10:
            type_b = 1

        elif acc_type <= 16:
            type_c = 1

        elif acc_type <= 33:
            type_d = 1

        elif acc_type <= 43:
            type_e = 1

        elif acc_type <= 49:
            type_f = 1

        elif acc_type <= 53:
            type_g = 1

        elif acc_type <= 63:
            type_h = 1

        elif acc_type <= 67:
            type_i = 1

        elif acc_type <= 75:
            type_j = 1

        elif acc_type <= 85:
            type_k = 1

        elif acc_type <= 91:
            type_l = 1

        elif acc_type <= 99:
            type_m = 1

        accidents_reindex.at[st_case, 'ACC_TYPE_A'] = type_a
        accidents_reindex.at[st_case, 'ACC_TYPE_B'] = type_b
        accidents_reindex.at[st_case, 'ACC_TYPE_C'] = type_c
        accidents_reindex.at[st_case, 'ACC_TYPE_D'] = type_d
        accidents_reindex.at[st_case, 'ACC_TYPE_E'] = type_e
        accidents_reindex.at[st_case, 'ACC_TYPE_F'] = type_f
        accidents_reindex.at[st_case, 'ACC_TYPE_G'] = type_g
        accidents_reindex.at[st_case, 'ACC_TYPE_H'] = type_h
        accidents_reindex.at[st_case, 'ACC_TYPE_I'] = type_i
        accidents_reindex.at[st_case, 'ACC_TYPE_J'] = type_j
        accidents_reindex.at[st_case, 'ACC_TYPE_K'] = type_k
        accidents_reindex.at[st_case, 'ACC_TYPE_L'] = type_l
        accidents_reindex.at[st_case, 'ACC_TYPE_M'] = type_m
        
        
        prev_case = st_case
            
        

accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_D  ACC_TYPE_E  ACC_TYPE_F  ACC_TYPE_G  \
# ST_CASE                   ...
# 410001         13      2  ...           0           0           0           0
# 410002          4      4  ...           0           0           0           0
# 410003         16      6  ...           0           0           0           0
# 410004          4      3  ...           0           0           0           0
# 410006          1      1  ...           0           0           0           0
# ...           ...    ...  ...         ...         ...         ...         ...
# 410293          4      6  ...           0           0           0           0
# 410294          2      2  ...           0           0           0           0
# 410295         11      1  ...           0           0           0           0
# 410296          4      4  ...           0           0           0           0
# 410297         14      6  ...           0           0           0           0
#
#          ACC_TYPE_H  ACC_TYPE_I  ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  \
# ST_CASE
# 410001            0           0           1           0           0
# 410002            0           0           0           0           0
# 410003            0           0           0           0           0
# 410004            0           0           0           0           0
# 410006            0           0           0           0           0
# ...             ...         ...         ...         ...         ...
# 410293            0           0           0           0           0
# 410294            0           0           0           0           0
# 410295            0           0           0           0           0
# 410296            0           0           0           0           0
# 410297            0           0           0           0           0
#
#          ACC_TYPE_M
# ST_CASE
# 410001            0
# 410002            0
# 410003            0
# 410004            0
# 410006            0
# ...             ...
# 410293            0
# 410294            0
# 410295            0
# 410296            0
# 410297            1
#
# [292 rows x 59 columns]

# %%
# adding method of distraction to accidents
accidents_reindex['MDRDSTRD'] = 0

# %%
for index in reindex_dis.index:
    st_case = index[0]
    mdrdstrd = reindex_dis.loc[index]['MDRDSTRD']
            
    if (mdrdstrd == 96) or (mdrdstrd == 99):
        accidents_reindex.at[st_case, 'MDRDSTRD'] = 99
    
    else:
        accidents_reindex.at[st_case, 'MDRDSTRD'] = mdrdstrd
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  ACC_TYPE_I  \
# ST_CASE                   ...
# 410001         13      2  ...           0           0           0           0
# 410002          4      4  ...           0           0           0           0
# 410003         16      6  ...           0           0           0           0
# 410004          4      3  ...           0           0           0           0
# 410006          1      1  ...           0           0           0           0
# ...           ...    ...  ...         ...         ...         ...         ...
# 410293          4      6  ...           0           0           0           0
# 410294          2      2  ...           0           0           0           0
# 410295         11      1  ...           0           0           0           0
# 410296          4      4  ...           0           0           0           0
# 410297         14      6  ...           0           0           0           0
#
#          ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD  MVIOLATN
# ST_CASE
# 410001            1           0           0           0        99         0
# 410002            0           0           0           0         0         0
# 410003            0           0           0           0        99         1
# 410004            0           0           0           0        99         0
# 410006            0           0           0           0         0         0
# ...             ...         ...         ...         ...       ...       ...
# 410293            0           0           0           0        99         0
# 410294            0           0           0           0        99         0
# 410295            0           0           0           0        99         1
# 410296            0           0           0           0        99         1
# 410297            0           0           0           1        99        99
#
# [292 rows x 61 columns]

# %%
# adding mviolatn to accidents
accidents_reindex['MVIOLATN'] = 0

# %%
for index in reindex_vio.index:
    st_case = index[0]
    mviolatn = reindex_vio.loc[index]['MVIOLATN'].values
            
    if mviolatn[0] == 0:
        accidents_reindex.at[st_case, 'MVIOLATN'] = 0
        
    elif (mviolatn[0] == 99) or (mviolatn[0] == 97) or (mviolatn[0] == 95):
        accidents_reindex.at[st_case, 'MVIOLATN'] = 99
    
    else:
        accidents_reindex.at[st_case, 'MVIOLATN'] = mviolatn[0]
        
accidents_reindex
# Out:
#          VE_TOTAL  PEDS  PERSONS  COUNTY  MONTH  DAY_WEEK  YEAR  HOUR  \
# ST_CASE
# 410001          2     0        2      33      1         3  2013    15
# 410002          1     1        1       3      1         3  2013    12
# 410003          1     0        4      51      1         4  2013     6
# 410004          1     0        1      33      1         6  2013    21
# 410006          1     0        1      19      1         5  2013    11
# ...           ...   ...      ...     ...    ...       ...   ...   ...
# 410293          1     1        1      11     10         5  2013    15
# 410294          1     2        1      33     10         4  2013     0
# 410295          1     0        7      51     11         5  2013    19
# 410296          1     0        2      11     11         6  2013    99
# 410297          2     0        2      39     12         2  2013     8
#
#          ROAD_FNC  ROUTE  ...  ACC_TYPE_F  ACC_TYPE_G  ACC_TYPE_H  ACC_TYPE_I  \
# ST_CASE                   ...
# 410001         13      2  ...           0           0           0           0
# 410002          4      4  ...           0           0           0           0
# 410003         16      6  ...           0           0           0           0
# 410004          4      3  ...           0           0           0           0
# 410006          1      1  ...           0           0           0           0
# ...           ...    ...  ...         ...         ...         ...         ...
# 410293          4      6  ...           0           0           0           0
# 410294          2      2  ...           0           0           0           0
# 410295         11      1  ...           0           0           0           0
# 410296          4      4  ...           0           0           0           0
# 410297         14      6  ...           0           0           0           0
#
#          ACC_TYPE_J  ACC_TYPE_K  ACC_TYPE_L  ACC_TYPE_M  MDRDSTRD  MVIOLATN
# ST_CASE
# 410001            1           0           0           0        99         0
# 410002            0           0           0           0         0         0
# 410003            0           0           0           0        99         1
# 410004            0           0           0           0        99         0
# 410006            0           0           0           0         0         0
# ...             ...         ...         ...         ...       ...       ...
# 410293            0           0           0           0        99         0
# 410294            0           0           0           0        99         0
# 410295            0           0           0           0        99         1
# 410296            0           0           0           0        99         1
# 410297            0           0           0           1        99        99
#
# [292 rows x 61 columns]

# %%
# Saving to a csv that still needs to be encoded
accidents_reindex.to_csv('Resources/cleaned_data/accidents_2013_unencoded.csv')
